# %% [markdown]
# #### IMPORTACIONES:

# %% [markdown]
# >import pandas as pd
# >
# >import numpy as np
# >
# >import seaborn as sns
# >
# >import matplotlib.pyplot as plt
# >
# >from scipy.stats import (pearsonr, f_oneway, ttest_ind, shapiro, mannwhitneyu, kruskal)
# >
# >import statsmodels.api as sm
# >
# >import scipy.stats as stats
# >
# >from itertools import combinations
# >
# >from statsmodels.stats.multitest import multipletests
# >
# >from statsmodels.stats.multicomp import pairwise_tukeyhsd
# >
# >import warnings
# >
# >from scipy.stats import ttest_1samp, ttest_ind, levene, ttest_rel, wilcoxon, f_oneway, ks_2samp, spearmanr
# >
# >warnings.filterwarnings("ignore", category=UserWarning)

# %% [markdown]
# #### PRIMER ANALISIS

# %% [markdown]
# 1. Un head()para ver las primeras filas de mi base de datos
#
# 2. Un tail() para ver las ultimas filas
#
# 3. info() para ver la informacion general de mi base de datos
#
# 4. shape para ver el total de filas y columnas
#
# 5. describe incluide object y otro exclude object para ver las estadisticas descriptivas
#
# 6. isna().sum() para ver si mi base de datos tiene valores nulos y despues otro .sum() para ver el total
#
# 7. .duplicated().sum() para ver si tengo valores duplicados
#
# 8. unknowns= (anime =="Unknown").sum().sum() para ver los valores llamados unknown

# %% [markdown]
# #### LIMPIEZA

# %% [markdown]
# 1. Visualizar los valores nulos con un countplot
#
# 2. .copy() para no alterar mi base de datos original
#
# 3. Borrar columnas innecesarias
#
# 4. .dropduplicates para borrar los valores duplicados
#
# ##### COLUMNAS: AIRED
#
# 1. Un regex para separar el mes de salida y el año en una columna llamada meses y luego otro para separar la columna meses en month aired y year aired
#
# 2. Comprobar otra vez los nan y arreglarlos con un fillna por ahora
#
# ##### COLUMNAS: PREMIERED
#
# 1. Una funcion lambda para que segun el mes de lanzamiento me ponga en la columna premiered la estacion del año que le corresponde y quitar los unknowns
#
# 2. nans y unknowns de la columna year aired y year season
#
# 3. El año de la columna Year Aired que este con unknowns en le voy a poner el año que tenga year season
#
# 4. En la columna generos los valores vienen en lista asi que con un get dummies los he separado y puesto en otro dataframe
#
# ##### COLUMNA RATING
#
# 1. Un regex para separar la R, PG, G y que solo se vea la columna con esos. Despues voy a quitar los unknowns sacando el valor mas comun del rating por genero
#
# ##### COLUMNA DURATION
#
# 1. Convertir todas las duraciones en minutos para luego poder analizarlo mejor con regex y bucles
#
# ##### COLUMNA ENGLISH NAME
#
# 1. Me sera mas facil ver los animes con el nombre en ingles pero esta incompleto asi que los valores unknown los voy a sustituir por los nombres que estan en la columna name con una funcion lambda
#
# ##### Eliminar lo que no me interesa:
#
# 1. Elimino ya todas las columnas que no me hacen falta

# %% [markdown]
# #### ANALISIS EXPLORATORIO

# %% [markdown]
# 1. Subir dataframe limpio, el de generos y uno de valores numericos
#
# 2. Significado de las columnas
#
# 3. Informacion general, describe, into, shape
#
# 4. Correlacion de todos los valores numericos de mi dataframe y heatmap
#
# 5. Analisis univariante:
#
# - Medidas de tendencia central con un hisplot
#
# - Un countplot de tipos de anime hay
#
# 6. Analisis bivariante
#
# - Un lineplot de las 10 series y peliculas de anime con mas puntuacion
#
# - Correlacion entre la puntuacion media y popularidad
#
# - Correlacion de la puntuacion media con animes completados
#
# 7. Analisis multivariante
#
# - Relacion entre favoritos, popularidad y animes completados
#
# - Relacion entre popularidad miembros, abandonados y pausados
#
# - Relacion de la popularidad y score entre animes de tipo tv y animes de tipo pelicula

# %% [markdown]
# #### TEST DE HIPOTESIS

# %% [markdown]
# 1. ¿Existe relación entre la puntuación media y la popularidad?
#
# - CORRELACION DE PEARSON
#
# 2. ¿Las puntuaciones se puede ver afectada por la duracion del anime?
#
# - CORRELACION DE PEARSON
#
# 3. ¿Los animes estrenados en ciertas estaciones del año pueden tener puntuaciones más altas?
#
# - Prueba de Kruskall-Wallis
#
# 4. ¿El número de espectadores que han completado un anime está positivamente correlacionado con su puntuación?
#
# - Correlacion de spearman
#
# 5. ¿Tiene impacto la duración en la popularidad?
#
# - He tenido que hacer una regresion lineal ya que el resto me daba de resultado nan y buscando me salio que esa era la mejor opcion
#
# 6. ¿Los animes con clasificaciones de edad más altas pueden tener menor popularidad y score, ya que restringen al público potencial?
#
# - Prueba de Krustall-wallis
#
# 7. ¿Hay evidencia para afirmar que la puntuación promedio de las series de anime no es la misma que la media general de todas las puntuaciones de anime?
#
# - Prueba T
#
# 8. ¿Hay evidencia para afirmar que la puntuación promedio de las peliculas de anime no es la misma que la media general de todas las puntuaciones de anime?
#
# - Prueba T
