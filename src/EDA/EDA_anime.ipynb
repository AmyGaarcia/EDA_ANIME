# %% [markdown]
# <img src="./data/foto-portada.jpg" alt="EVANGELION" width="98%" />

# %% [markdown]
# <h1 style="font-size: 6em; text-align: center;"><span style="color:#D7DBDD">LA POPULARIDAD DEL ANIME</span></h1>

# %% [markdown]
#  # <span style="color:#AEB6BF   "> ANALISIS EXPLORATORIO DE DATOS(EDA) DE LA POPULARIDAD DEL ANIME </span>

# %% [markdown]
# ## <span style="color:#85929E "> TEMA </span>

# %% [markdown]
# ANIME. El anime es una forma de expresión artística japonesa que ha ganado popularidad a nivel mundial, ha cautivado a audiencias de todas las edades con sus historias, personajes memorables y estilos visuales. Asi que vamos a realizar un análisis exploratorio de datos para estudiar los factores que contribuyen a la popularidad en el mundo del anime.

# %% [markdown]
# ### <span style="color:#85929E "> OBJETIVO </span>

# %% [markdown]
# El objetivo de este EDA es estudiar lo que resuena con la audiencia y contribuye a la popularidad en el mundo del anime

# %% [markdown]
# ## <span style="color:#85929E "> IMPORTACIONES </span>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import (pearsonr, f_oneway, ttest_ind, shapiro, mannwhitneyu, kruskal)
import statsmodels.api as sm
import scipy.stats as stats
from itertools import combinations
from statsmodels.stats.multitest import multipletests
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import warnings
from scipy.stats import ttest_1samp, ttest_ind, levene, ttest_rel, wilcoxon, f_oneway, ks_2samp, spearmanr

warnings.filterwarnings("ignore", category=UserWarning)

# %% [markdown]
# ## <span style="color:#85929E "> DATASETS Y FUENTES ALTERNATIVAS DE DATOS </span>

# %% [markdown]
# >[KAGGLE](https://www.kaggle.com/datasets)

# %%
anime = pd.read_csv("./data/anime.csv")

# %% [markdown]
# ## <span style="color:#85929E "> PRIMER ANALISIS </span>

# %%
# HACER UN HEAD DE MI BASE DE DATOS PARA VER LAS PRIMERAS FILAS
anime.head()
# Out:
#    anime_id                             Name  Score  \
# 0         1                     Cowboy Bebop   8.78
# 1         5  Cowboy Bebop: Tengoku no Tobira   8.39
# 2         6                           Trigun   8.24
# 3         7               Witch Hunter Robin   7.27
# 4         8                   Bouken Ou Beet   6.98
#
#                                               Genres            English name  \
# 0    Action, Adventure, Comedy, Drama, Sci-Fi, Space            Cowboy Bebop
# 1              Action, Drama, Mystery, Sci-Fi, Space  Cowboy Bebop:The Movie
# 2  Action, Sci-Fi, Adventure, Comedy, Drama, Shounen                  Trigun
# 3  Action, Mystery, Police, Supernatural, Drama, ...      Witch Hunter Robin
# 4          Adventure, Fantasy, Shounen, Supernatural  Beet the Vandel Buster
#
#                       Japanese name  \
# 0                         カウボーイビバップ
# 1                    カウボーイビバップ 天国の扉
# 2                             トライガン
# 3  Witch Hunter ROBIN (ウイッチハンターロビン)
# 4                            冒険王ビィト
#
#                                            sypnopsis   Type Episodes  \
# 0  In the year 2071, humanity has colonized sever...     TV       26
# 1  other day, another bounty—such is the life of ...  Movie        1
# 2  Vash the Stampede is the man with a $$60,000,0...     TV       26
# 3  ches are individuals with special powers like ...     TV       26
# 4  It is the dark century and the people are suff...     TV       52
#
#                           Aired  ...         Duration  \
# 0   Apr 3, 1998 to Apr 24, 1999  ...  24 min. per ep.
# 1                   Sep 1, 2001  ...    1 hr. 55 min.
# 2   Apr 1, 1998 to Sep 30, 1998  ...  24 min. per ep.
# 3   Jul 2, 2002 to Dec 24, 2002  ...  25 min. per ep.
# 4  Sep 30, 2004 to Sep 29, 2005  ...  23 min. per ep.
#
#                            Rating  Ranked Popularity  Members Favorites  \
# 0  R - 17+ (violence & profanity)    28.0         39  1251960     61971
# 1  R - 17+ (violence & profanity)   159.0        518   273145      1174
# 2       PG-13 - Teens 13 or older   266.0        201   558913     12944
# 3       PG-13 - Teens 13 or older  2481.0       1467    94683       587
# 4                   PG - Children  3710.0       4369    13224        18
#
#   Watching  Completed  On-Hold  Dropped
# 0   105808     718161    71513    26678
# 1     4143     208333     1935      770
# 2    29113     343492    25465    13925
# 3     4300      46165     5121     5378
# 4      642       7314      766     1108
#
# [5 rows x 25 columns]

# %%
# HACER UN TAIL DE MI BASE DE DATOS PARA VER LAS ULTIMAS FILAS
anime.tail()
# Out:
#        anime_id                             Name  Score  \
# 14947     48481  Daomu Biji Zhi Qinling Shen Shu   6.51
# 14948     48483                     Mieruko-chan   6.51
# 14949     48488  Higurashi no Naku Koro ni Sotsu   6.51
# 14950     48491      Yama no Susume: Next Summit   6.51
# 14951     48492                    Scarlet Nexus   6.51
#
#                                                   Genres  \
# 14947                   Adventure, Mystery, Supernatural
# 14948                       Comedy, Horror, Supernatural
# 14949  Mystery, Dementia, Horror, Psychological, Supe...
# 14950                   Adventure, Slice of Life, Comedy
# 14951                                    Action, Fantasy
#
#                           English name       Japanese name  \
# 14947                          Unknown           盗墓笔记之秦岭神树
# 14948                          Unknown             見える子ちゃん
# 14949  Higurashi:When They Cry – SOTSU          ひぐらしのなく頃に卒
# 14950                          Unknown  ヤマノススメ Next Summit
# 14951                          Unknown       SCARLET NEXUS
#
#                                                sypnopsis Type Episodes  \
# 14947  No synopsis information has been added to this...  ONA  Unknown
# 14948  ko is a typical high school student whose life...   TV  Unknown
# 14949          Sequel to Higurashi no Naku Koro ni Gou .   TV  Unknown
# 14950                          New Yama no Susume anime.   TV  Unknown
# 14951  Solar calendar year 2020: grotesque organisms ...   TV  Unknown
#
#                   Aired  ... Duration                          Rating Ranked  \
# 14947  Apr 4, 2021 to ?  ...  Unknown                         Unknown    NaN
# 14948         2021 to ?  ...  Unknown                         Unknown    NaN
# 14949    Jul, 2021 to ?  ...  Unknown  R - 17+ (violence & profanity)    NaN
# 14950           Unknown  ...  Unknown       PG-13 - Teens 13 or older    NaN
# 14951    Jul, 2021 to ?  ...  Unknown                         Unknown    NaN
#
#       Popularity Members Favorites Watching  Completed  On-Hold  Dropped
# 14947      13116     354         6        0          0        0        0
# 14948      17562    7010        70       14          0       14        0
# 14949      17558   11309        48        3          0        0        0
# 14950      17565    1386         2       13          2        2        1
# 14951      17563     310         0        4          0        1        1
#
# [5 rows x 25 columns]

# %% [markdown]
# Veo que hay algunosvalores unknowns

# %%
#VER LA INFORMACION DE LA BASE DE DATOS INICIAL
anime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14952 entries, 0 to 14951
# Data columns (total 25 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   anime_id       14952 non-null  int64
#  1   Name           14952 non-null  object
#  2   Score          14952 non-null  float64
#  3   Genres         14952 non-null  object
#  4   English name   14952 non-null  object
#  5   Japanese name  14952 non-null  object
#  6   sypnopsis      13602 non-null  object
#  7   Type           14952 non-null  object
#  8   Episodes       14952 non-null  object
#  9   Aired          14952 non-null  object
#  10  Premiered      14952 non-null  object
#  11  Producers      14952 non-null  object
#  12  Licensors      14952 non-null  object
#  13  Studios        14952 non-null  object
#  14  Source         14952 non-null  object
#  15  Duration       14952 non-null  object
#  16  Rating         14952 non-null  object
#  17  Ranked         13231 non-null  float64
#  18  Popularity     14952 non-null  int64
#  19  Members        14952 non-null  int64
#  20  Favorites      14952 non-null  int64
#  21  Watching       14952 non-null  int64
#  22  Completed      14952 non-null  int64
#  23  On-Hold        14952 non-null  int64
#  24  Dropped        14952 non-null  int64
# dtypes: float64(2), int64(8), object(15)
# memory usage: 2.9+ MB

# %%
#VER LAS FILAS Y COLUMNAS QUE TIENE
anime.shape
# Out:
# (14952, 25)

# %%
# VEO TODAS LAS COLUMNAS
anime.columns
# Out:
# Index(['anime_id', 'Name', 'Score', 'Genres', 'English name', 'Japanese name',
#        'sypnopsis', 'Type', 'Episodes', 'Aired', 'Premiered', 'Producers',
#        'Licensors', 'Studios', 'Source', 'Duration', 'Rating', 'Ranked',
#        'Popularity', 'Members', 'Favorites', 'Watching', 'Completed',
#        'On-Hold', 'Dropped'],
#       dtype='object')

# %%
# HAGO UN DESCRIBE INCLUYENDO OBJECTS 
anime.describe(include=object).round(2)
# Out:
#                                                      Name  Genres  \
# count                                               14952   14952
# unique                                              14949    4839
# top     Maou Gakuin no Futekigousha: Shijou Saikyou no...  Hentai
# freq                                                    3     967
#
#        English name Japanese name  \
# count         14952         14952
# unique         6252         14176
# top         Unknown       Unknown
# freq           8554            33
#
#                                                 sypnopsis   Type Episodes  \
# count                                               13602  14952    14952
# unique                                              12890      7      199
# top     No synopsis information has been added to this...     TV        1
# freq                                                  466   4650     6563
#
#           Aired Premiered Producers Licensors  Studios Source  \
# count     14952     14952     14952     14952    14952  14952
# unique    10722       231      3714       231     1048     16
# top     Unknown   Unknown   Unknown   Unknown  Unknown  Manga
# freq        185     10456      6152     11007     4912   3764
#
#                Duration                     Rating
# count             14952                      14952
# unique              301                          7
# top     24 min. per ep.  PG-13 - Teens 13 or older
# freq               1706                       5975

# %%
# HAGO UN DESCRIBE EXCLUYENDO LOS OBJECTS PARA VER LAS ESTADISTICAS DESCRIPTIVAS DE LA BASE DE DATOS
anime.describe(exclude=object).round(2)
# Out:
#        anime_id     Score    Ranked  Popularity     Members  Favorites  \
# count  14952.00  14952.00  13231.00    14952.00    14952.00   14952.00
# mean   19017.43      6.51   6829.85     7465.97    40686.48     537.63
# std    14588.76      0.81   4168.93     4313.17   134874.35    4399.02
# min        1.00      1.85      1.00        1.00      200.00       0.00
# 25%     4602.50      6.08   3309.50     3732.00      736.00       1.00
# 50%    16729.00      6.51   6618.00     7466.50     3493.50       6.00
# 75%    33513.25      7.01   9942.00    11194.00    19193.25      47.00
# max    48492.00      9.19  15780.00    17565.00  2589552.00  183914.00
#
#         Watching   Completed    On-Hold    Dropped
# count   14952.00    14952.00   14952.00   14952.00
# mean     2619.81    25943.10    1121.31    1377.86
# std     15190.10    98127.29    4613.76    5110.87
# min         0.00        0.00       0.00       0.00
# 25%        27.00      246.00      14.00      48.00
# 50%       127.00     1515.50      78.00     102.00
# 75%       723.00     9797.00     388.25     377.00
# max    887333.00  2182587.00  187919.00  174710.00

# %%
#VER SI MI BASE DE DATOS TIENE VALORES NULOS
anime.isna().sum()
# Out:
# anime_id            0
# Name                0
# Score               0
# Genres              0
# English name        0
# Japanese name       0
# sypnopsis        1350
# Type                0
# Episodes            0
# Aired               0
# Premiered           0
# Producers           0
# Licensors           0
# Studios             0
# Source              0
# Duration            0
# Rating              0
# Ranked           1721
# Popularity          0
# Members             0
# Favorites           0
# Watching            0
# Completed           0
# On-Hold             0
# Dropped             0
# dtype: int64

# %%
# VEO EL TOTAL
anime.isna().sum().sum()
# Out:
# 3071

# %%
# EL PORCENTAJE DE VALORES NULOS EN CADA COLUMNA
anime.isna().sum()/len(anime)*100
# Out:
# anime_id          0.000000
# Name              0.000000
# Score             0.000000
# Genres            0.000000
# English name      0.000000
# Japanese name     0.000000
# sypnopsis         9.028892
# Type              0.000000
# Episodes          0.000000
# Aired             0.000000
# Premiered         0.000000
# Producers         0.000000
# Licensors         0.000000
# Studios           0.000000
# Source            0.000000
# Duration          0.000000
# Rating            0.000000
# Ranked           11.510166
# Popularity        0.000000
# Members           0.000000
# Favorites         0.000000
# Watching          0.000000
# Completed         0.000000
# On-Hold           0.000000
# Dropped           0.000000
# dtype: float64

# %%
# COMPROBAR SI TENGO VALORES DUPLICADOS
anime.duplicated().sum()
# Out:
# 0

# %%
# Y COMO EN EL .TAIL() HE VISTO QUE HAY VALORES UNKNOWN QUERIA VER EL TOTAL
unknowns= (anime =="Unknown").sum().sum()

unknowns
# Out:
# 45783

# %%
#QUIERO VER CUANDOS UNKNOWNS HAY EN CADA COLUMNA
unknowns= (anime =="Unknown").sum()
unknowns
# Out:
# anime_id             0
# Name                 0
# Score                0
# Genres              46
# English name      8554
# Japanese name       33
# sypnopsis            0
# Type                36
# Episodes           415
# Aired              185
# Premiered        10456
# Producers         6152
# Licensors        11007
# Studios           4912
# Source            2974
# Duration           460
# Rating             553
# Ranked               0
# Popularity           0
# Members              0
# Favorites            0
# Watching             0
# Completed            0
# On-Hold              0
# Dropped              0
# dtype: int64

# %% [markdown]
# ## <span style="color:#85929E "> LIMPIEZA </span>

# %% [markdown]
# #### Valores Nan

# %% [markdown]
# ><span style="font-size: 25px; color:#839192">Ya he visto que tengo 3071 valores nan y quiero visualizar la proporcion de mis datos nulos con un sns.countplot:</span>

# %%
#GRAFICA PARA VER LA PROPORCION DE VALORES NULOS Y NO NULOS
anime_nulos= anime.isnull()

plt.figure(figsize=(4,6))
sns.set(style="whitegrid")
sns.countplot(data=anime_nulos.melt(), y="variable", hue="value", palette="Paired" )
plt.title("Valores nulos por columnas", color="Grey", fontsize=20)
plt.ylabel("Columnas", color="Grey", fontsize=10)
plt.xlabel("Numero de valores nulos", color="Grey", fontsize=10)
plt.xticks(rotation=0, ha="right")
plt.legend(bbox_to_anchor=(1,0.6))

plt.show()

# %% [markdown]
# ><span style="font-size: 25px; color:#839192">Hago un .copy() y empiezo a eliminar columnas que no me interesan:</span>

# %%
#AHORA QUE VOY A MODIFICAR COSAS VOY A HACER UN COPY PARA NO ALTERAR LA BASE DE DATOS INICIAL
anime_EDA=anime.copy()

# %% [markdown]
# ><span style="font-size: 20px; color:#839192">He hecho una exploración por el dataset y veo que casi la mayoría de las filas de las columnas que no tienen nan tiene valor unknowns en la fila que ranked tienen nan. así que desde mi punto de vista esas filas no van a ser útiles para analizar y considero que mejor borrarlas ya que no van a aportar nada en el análisis:</span>

# %%
#BORRAR ESTAS COLUMNAS Y FILAS YA QUE DESDE MI PUNTO DE VISTA SON INNECESARIAS PARA EL ANALISIS QUE VOY A HACER

anime_EDA= anime_EDA.dropna(subset=["Ranked"]) #ELIMINO LAS FILAS RANKED

# %% [markdown]
# ><span style="font-size: 20px; color:#839192">Como las columnas ranked y sinopsis no las voy analizar por que la sinopsis no me es util y el ranked tampoco. ya con la popularidad, el score y favoritos tengo para ver la popularidad. Así que las elimino con un .dropna():</span>

# %%
anime_EDA.drop(["Ranked","sypnopsis"], axis=1, inplace=True) #ELIMINO LAS COLUMNAS RANKED Y SINOPSOS

# %%
# COMPROBAR SI SE HA BORRADO CORRECTAMENTE ESAS COLUMNAS Y NO HAY NAN
anime_EDA.isna().sum()
# Out:
# anime_id         0
# Name             0
# Score            0
# Genres           0
# English name     0
# Japanese name    0
# Type             0
# Episodes         0
# Aired            0
# Premiered        0
# Producers        0
# Licensors        0
# Studios          0
# Source           0
# Duration         0
# Rating           0
# Popularity       0
# Members          0
# Favorites        0
# Watching         0
# Completed        0
# On-Hold          0
# Dropped          0
# dtype: int64

# %% [markdown]
# #### Valores duplicados

# %% [markdown]
# ><span style="font-size: 20px; color:#839192">En el primer análisis vi que no hay valores duplicados así que voy a comprobarlo y hacer un drop duplicated por si acaso:</span>

# %%
#QUIERO VER CUANTOS VALORES DUPLICADOS TENGO 
anime.duplicated().sum()
# Out:
# 0

# %%
#QUIERO BORRAR LAS FILAS DUPLICADAS, POR SI HUBIERA
anime_EDA.drop_duplicates()
# Out:
#        anime_id                                            Name  Score  \
# 0             1                                    Cowboy Bebop   8.78
# 1             5                 Cowboy Bebop: Tengoku no Tobira   8.39
# 2             6                                          Trigun   8.24
# 3             7                              Witch Hunter Robin   7.27
# 4             8                                  Bouken Ou Beet   6.98
# ...         ...                                             ...    ...
# 14916     47591    Kuro Gal ni Natta kara Shinyuu to shitemita.   6.51
# 14917     47614    Nu Wushen de Canzhuo Spring Festival Special   6.83
# 14918     47616  Yakusoku no Neverland 2nd Season: Michishirube   4.81
# 14924     47795                  Ai Zai Xi Yuan Qian 2nd Season   6.51
# 14943     48456                             SK∞: Crazy Rock Jam   6.52
#
#                                                   Genres  \
# 0        Action, Adventure, Comedy, Drama, Sci-Fi, Space
# 1                  Action, Drama, Mystery, Sci-Fi, Space
# 2      Action, Sci-Fi, Adventure, Comedy, Drama, Shounen
# 3      Action, Mystery, Police, Supernatural, Drama, ...
# 4              Adventure, Fantasy, Shounen, Supernatural
# ...                                                  ...
# 14916                                Romance, Shounen Ai
# 14917                              Slice of Life, Comedy
# 14918  Mystery, Psychological, Supernatural, Thriller...
# 14924                                   Fantasy, Romance
# 14943                                     Comedy, Sports
#
#                                          English name  \
# 0                                        Cowboy Bebop
# 1                              Cowboy Bebop:The Movie
# 2                                              Trigun
# 3                                  Witch Hunter Robin
# 4                              Beet the Vandel Buster
# ...                                               ...
# 14916                                         Unknown
# 14917  Cooking with Valkyries Spring Festival Special
# 14918     The Promised Neverland Season 2 Episode 5.5
# 14924              Immemorial Love For You 2nd Season
# 14943                                         Unknown
#
#                             Japanese name     Type Episodes  \
# 0                               カウボーイビバップ       TV       26
# 1                          カウボーイビバップ 天国の扉    Movie        1
# 2                                   トライガン       TV       26
# 3        Witch Hunter ROBIN (ウイッチハンターロビン)       TV       26
# 4                                  冒険王ビィト       TV       52
# ...                                   ...      ...      ...
# 14916                  黒ギャルになったから親友としてみた。       TV  Unknown
# 14917                             Unknown  Special        1
# 14918                   約束のネバーランド 特別編「道標」  Special        1
# 14924                           爱在西元前 第二季      ONA       16
# 14943  SK∞ エスケーエイト #9.5 PART『クレイジーロックJAM』  Special        1
#
#                               Aired    Premiered  ...    Source  \
# 0       Apr 3, 1998 to Apr 24, 1999  Spring 1998  ...  Original
# 1                       Sep 1, 2001      Unknown  ...  Original
# 2       Apr 1, 1998 to Sep 30, 1998  Spring 1998  ...     Manga
# 3       Jul 2, 2002 to Dec 24, 2002  Summer 2002  ...  Original
# 4      Sep 30, 2004 to Sep 29, 2005    Fall 2004  ...     Manga
# ...                             ...          ...  ...       ...
# 14916             Feb 11, 2021 to ?  Winter 2021  ...     Manga
# 14917                  Feb 11, 2021      Unknown  ...      Game
# 14918                  Feb 12, 2021      Unknown  ...     Manga
# 14924             Feb 14, 2021 to ?      Unknown  ...   Unknown
# 14943                  Mar 14, 2021      Unknown  ...  Original
#
#               Duration                          Rating Popularity  Members  \
# 0      24 min. per ep.  R - 17+ (violence & profanity)         39  1251960
# 1        1 hr. 55 min.  R - 17+ (violence & profanity)        518   273145
# 2      24 min. per ep.       PG-13 - Teens 13 or older        201   558913
# 3      25 min. per ep.       PG-13 - Teens 13 or older       1467    94683
# 4      23 min. per ep.                   PG - Children       4369    13224
# ...                ...                             ...        ...      ...
# 14916           4 min.                R+ - Mild Nudity       7387     3636
# 14917          10 min.                   PG - Children      11973      540
# 14918          23 min.  R - 17+ (violence & profanity)       4398    13070
# 14924          Unknown                         Unknown      12411      463
# 14943          23 min.       PG-13 - Teens 13 or older       4830    10722
#
#       Favorites  Watching  Completed  On-Hold  Dropped
# 0         61971    105808     718161    71513    26678
# 1          1174      4143     208333     1935      770
# 2         12944     29113     343492    25465    13925
# 3           587      4300      46165     5121     5378
# 4            18       642       7314      766     1108
# ...         ...       ...        ...      ...      ...
# 14916        90       768          3       79       35
# 14917         8        51        168       18        2
# 14918        90      1183       8196      119      202
# 14924        35        40          0        7        7
# 14943       167       739       7207       57       45
#
# [13231 rows x 23 columns]

# %%
#COMPRUEBO FILAS Y COLUMNAS OTRA VEZ
anime_EDA.shape
# Out:
# (13231, 23)

# %% [markdown]
# #### Columnas

# %% [markdown]
# ><span style="font-size: 20px; color:#839192">Quiero ver el contenido de algunas columnas ya que he visto que ya no tienen Nan pero si tienen algunos valores desconocidos(Unknown):</span>

# %%
#TOTAL DE UNKNOWNS EN EL DATAFRAME
unknowns= (anime_EDA =="Unknown").sum().sum()

unknowns
# Out:
# 38449

# %% [markdown]
# ##### Columna Aired/Month Aired:

# %%
#VER PARTE DEL CONTENIDO DE ESA COLUMNA
anime_EDA["Aired"].unique()
# Out:
# array(['Apr 3, 1998 to Apr 24, 1999', 'Sep 1, 2001',
#        'Apr 1, 1998 to Sep 30, 1998', ..., 'Feb 11, 2021 to ?',
#        'Feb 12, 2021', 'Mar 14, 2021'], dtype=object)

# %% [markdown]
# ><span style="font-size: 20px; color:#839192">En la columna Aired he visto que va a ser dificil de analizar por como estan las fechas, algunas tienen fecha de lanzamiento y fecha final o la fecha final con interrogacion</span>
# >
# ><span style="font-size: 20px; color:#839192">Asi que voy a hacer un regex para separar el mes de salida y el año en una columna llamada meses y luego otro para separar la columna meses en >month aired y year aired:</span>

# %% [markdown]
#      Lo he intentado hacer con pandas pero me dan muchos valores de NAT y algunos un poco raros asi que sigo con el regex

# %%
#AQUI HE HECHO UN REGEX PARA SEPARAR PARTE DE AIRED Y PODER CREAR DOS COLUMNAS SEPARADAS DE MES Y AÑO POR QUE ES LA UNICA MANERA QUE ME HA FUNCIONADO
anime_EDA["Meses"]= anime_EDA["Aired"].str.extract(r"(\w{3} \d{1,2}, \d{4})")

# %%
#SEPARAR LOS MESES Y Y METERLO EN UNA COLUMNA LLAMADA MES DE LANZAMIENTO
anime_EDA["Month Aired"] =anime_EDA["Meses"].str.extract(r"(\w{3})")

# %%
#LO MISMO CON EL AÑO
anime_EDA["Year Aired"] =anime_EDA["Meses"].str.extract(r", (\d{4})")

# %%
anime_EDA.head(4)
# Out:
#    anime_id                             Name  Score  \
# 0         1                     Cowboy Bebop   8.78
# 1         5  Cowboy Bebop: Tengoku no Tobira   8.39
# 2         6                           Trigun   8.24
# 3         7               Witch Hunter Robin   7.27
#
#                                               Genres            English name  \
# 0    Action, Adventure, Comedy, Drama, Sci-Fi, Space            Cowboy Bebop
# 1              Action, Drama, Mystery, Sci-Fi, Space  Cowboy Bebop:The Movie
# 2  Action, Sci-Fi, Adventure, Comedy, Drama, Shounen                  Trigun
# 3  Action, Mystery, Police, Supernatural, Drama, ...      Witch Hunter Robin
#
#                       Japanese name   Type Episodes  \
# 0                         カウボーイビバップ     TV       26
# 1                    カウボーイビバップ 天国の扉  Movie        1
# 2                             トライガン     TV       26
# 3  Witch Hunter ROBIN (ウイッチハンターロビン)     TV       26
#
#                          Aired    Premiered  ... Popularity  Members  \
# 0  Apr 3, 1998 to Apr 24, 1999  Spring 1998  ...         39  1251960
# 1                  Sep 1, 2001      Unknown  ...        518   273145
# 2  Apr 1, 1998 to Sep 30, 1998  Spring 1998  ...        201   558913
# 3  Jul 2, 2002 to Dec 24, 2002  Summer 2002  ...       1467    94683
#
#   Favorites Watching Completed On-Hold  Dropped        Meses  Month Aired  \
# 0     61971   105808    718161   71513    26678  Apr 3, 1998          Apr
# 1      1174     4143    208333    1935      770  Sep 1, 2001          Sep
# 2     12944    29113    343492   25465    13925  Apr 1, 1998          Apr
# 3       587     4300     46165    5121     5378  Jul 2, 2002          Jul
#
#    Year Aired
# 0        1998
# 1        2001
# 2        1998
# 3        2002
#
# [4 rows x 26 columns]

# %% [markdown]
# ><span style="font-size: 20px; color:#839192">Ahora tengo unas columnas que sobran que son Aired y Meses, asi que voy a eliminarlas y colocar month aired en otra posicion que no sea la ultima de dataframe:</span>

# %%
#ELIMINAR LAS COLUMNAS AIRED Y MESES CON .DROP()
anime_EDA.drop(columns=["Aired", "Meses"], inplace=True)

# %%
#COMO NO QUIERO QUE MES Y AÑO SEAN LAS ULTIMAS COLUMNAS VOY A CAMBIARLAS DE SITIO

#AQUI HAGO UN POP PARA LUEGO PODER INSERTARLO EN LA POSICION QUE QUIERA Y NO SEA LA ULTIMA COLUMNA, NO ME DEJABA SIN EL POP
mes = anime_EDA.pop("Month Aired")
anime_EDA.insert(7, "Month Aired", mes)

# %%
#LO PONGO EN LA POSICION DE AL LADO DE MES DE LANZAMIENTO
year= anime_EDA.pop("Year Aired")
anime_EDA.insert(8, "Year Aired", year)

# %%
anime_EDA.head(3)

#todo OK por ahora
# Out:
#    anime_id                             Name  Score  \
# 0         1                     Cowboy Bebop   8.78
# 1         5  Cowboy Bebop: Tengoku no Tobira   8.39
# 2         6                           Trigun   8.24
#
#                                               Genres            English name  \
# 0    Action, Adventure, Comedy, Drama, Sci-Fi, Space            Cowboy Bebop
# 1              Action, Drama, Mystery, Sci-Fi, Space  Cowboy Bebop:The Movie
# 2  Action, Sci-Fi, Adventure, Comedy, Drama, Shounen                  Trigun
#
#     Japanese name   Type Month Aired Year Aired Episodes  ...    Source  \
# 0       カウボーイビバップ     TV         Apr       1998       26  ...  Original
# 1  カウボーイビバップ 天国の扉  Movie         Sep       2001        1  ...  Original
# 2           トライガン     TV         Apr       1998       26  ...     Manga
#
#           Duration                          Rating Popularity  Members  \
# 0  24 min. per ep.  R - 17+ (violence & profanity)         39  1251960
# 1    1 hr. 55 min.  R - 17+ (violence & profanity)        518   273145
# 2  24 min. per ep.       PG-13 - Teens 13 or older        201   558913
#
#   Favorites Watching  Completed  On-Hold  Dropped
# 0     61971   105808     718161    71513    26678
# 1      1174     4143     208333     1935      770
# 2     12944    29113     343492    25465    13925
#
# [3 rows x 24 columns]

# %%
month= anime_EDA["Month Aired"].value_counts()

sns.set(style="whitegrid")
plt.figure(figsize=(10,5))
sns.barplot(x=month.index, y=month.values, hue=month.index, palette="rocket")
plt.title("los meses mas comunes para estrenos de animes", color="Grey", fontsize=17)
plt.xlabel("Meses", color="Grey", fontsize=10)
plt.ylabel("Numero de estrenos", color="Grey", fontsize=10)
plt.tick_params(axis="x", colors="grey")
plt.tick_params(axis="y", colors="grey")

# ES PARA PONER EL PORCENTAJE ARRIBA DE CADA COLUMNAA
for i, value in enumerate(month.values):
    porcentaje = (value /month.sum()) * 100
    plt.text(i, value+ 0.1, f"{porcentaje:.1f}%", ha="center",va="bottom", color="grey")

plt.show()

# %% [markdown]
# ><span style="font-size: 25px; color:#839192">En este grafico podemos ver que los meses mas comunes de estrenos de anime son en april y octubre</span>

# %% [markdown]
# ##### Comprobar otra vez los valores Nan y unknowns:

# %% [markdown]
# ><span style="font-size: 20px; color:#839192">Ahora es posible haya valores nan por la modificacion de la columna Aired</span>
# >
# ><span style="font-size: 20px; color:#839192">Voy a ver si hay valores nan y si es asi hare un fillna llamando unknown a los valores nan para despues poder hacer sacar los valores unknows basandome en la moda del mismo tipo de anime y estudios:</span>

# %%
anime_EDA.isna().sum()
# Out:
# anime_id           0
# Name               0
# Score              0
# Genres             0
# English name       0
# Japanese name      0
# Type               0
# Month Aired      934
# Year Aired       934
# Episodes           0
# Premiered          0
# Producers          0
# Licensors          0
# Studios            0
# Source             0
# Duration           0
# Rating             0
# Popularity         0
# Members            0
# Favorites          0
# Watching           0
# Completed          0
# On-Hold            0
# Dropped            0
# dtype: int64

# %%
#POR AHORA LOS VOY A LLAMAR A LOS VALORES NAN UNKOWNS PARA PASAR A LO SIGUIENTE Y QUE NO ME DE ERROR POR LOS NAN
anime_EDA["Month Aired"]= anime_EDA["Month Aired"].fillna("Unknown")

# %%
# MIRAR CUANTOS UNKNOWNS TENGO EN TOTAL
anime_EDA["Month Aired"].isin(["Unknown"]).sum()
# Out:
# 934

# %%
# LO MISMO CON EL AÑO
anime_EDA["Year Aired"]= anime_EDA["Year Aired"].fillna("Unknown")

# %%
anime_EDA["Year Aired"].isin(["Unknown"]).sum()
# Out:
# 934

# %% [markdown]
#     CON ESTO QUIERO SACAR LOS VALORES UNKNOWNS BASANDOME EN EL VALOR MAS FRECUENTE DEL MISMO TIPO DE ANIME Y ESTUDIOS

# %%
# AQUI VOY A CALCULAR EL MES MAS FRECUENTE POR GRIPO CREANDO UN DATAFRAME CON LOS MESES AGRUPADOS POR TYPE Y STUDIOS
mes =anime_EDA.groupby(["Type","Studios"])["Month Aired"].apply(lambda x:x.mode().iloc[0] if not x.empty else "Unknown").reset_index()

# %%
grupo= mes.set_index(["Type","Studios"])["Month Aired"].to_dict()

# %%
anime_EDA["Month Aired"]= anime_EDA.apply(lambda f :grupo.get((f["Type"], f["Studios"]),"Unknown") if f["Month Aired"] =="Unknown" else f["Month Aired"], axis=1)

# %%
# VER CUANTOS UNKNOWN HAY EN LA COLUMNA
anime_EDA["Month Aired"].isin(["Unknown"]).sum()
# Out:
# 625

# %% [markdown]
#      HE QUITADO ALGUNOS DE LA COLUMNA MONTH AIRED PERO TODAVIA QUEDAN 625 UNKNOWN

# %% [markdown]
# ##### Columna premiered/Season:

# %%
anime_EDA["Premiered"].unique()
# Out:
# array(['Spring 1998', 'Unknown', 'Summer 2002', 'Fall 2004',
#        'Spring 2005', 'Fall 2002', 'Spring 2004', 'Fall 1999',
#        'Fall 2001', 'Spring 2003', 'Fall 1995', 'Fall 1997',
#        'Winter 1996', 'Spring 2002', 'Winter 2005', 'Spring 2001',
#        'Spring 1999', 'Fall 2003', 'Summer 2003', 'Summer 2004',
#        'Fall 2005', 'Winter 2002', 'Summer 2005', 'Spring 1979',
#        'Spring 1985', 'Spring 1986', 'Spring 1993', 'Spring 1995',
#        'Spring 1996', 'Spring 1994', 'Winter 1994', 'Spring 2000',
#        'Fall 1996', 'Spring 1997', 'Winter 2004', 'Winter 1998',
#        'Summer 2001', 'Winter 1999', 'Fall 1998', 'Fall 1993',
#        'Summer 2000', 'Fall 2000', 'Winter 2003', 'Spring 1989',
#        'Winter 1986', 'Summer 1997', 'Summer 1999', 'Winter 1979',
#        'Winter 2001', 'Spring 1978', 'Winter 1973', 'Spring 1991',
#        'Fall 1973', 'Fall 1989', 'Fall 1994', 'Winter 1992', 'Fall 1979',
#        'Summer 1998', 'Winter 2000', 'Winter 2006', 'Summer 1995',
#        'Fall 1992', 'Summer 1985', 'Spring 1973', 'Spring 1984',
#        'Spring 1982', 'Spring 1992', 'Winter 1993', 'Summer 2006',
#        'Fall 1985', 'Winter 1991', 'Spring 1987', 'Spring 2006',
#        'Summer 1991', 'Winter 1987', 'Winter 1997', 'Winter 1995',
#        'Spring 1988', 'Summer 1987', 'Winter 1983', 'Spring 1980',
#        'Winter 1990', 'Spring 1976', 'Fall 1984', 'Fall 1991',
#        'Summer 1977', 'Fall 1982', 'Fall 1988', 'Summer 1994',
#        'Spring 1990', 'Fall 1986', 'Summer 1982', 'Spring 2007',
#        'Fall 1981', 'Summer 1984', 'Fall 1971', 'Fall 1977',
#        'Spring 1967', 'Spring 1981', 'Summer 1975', 'Fall 2006',
#        'Summer 1996', 'Fall 1978', 'Summer 1965', 'Winter 1970',
#        'Fall 1965', 'Winter 2007', 'Winter 1989', 'Fall 1974',
#        'Fall 1980', 'Winter 1976', 'Summer 2007', 'Summer 1980',
#        'Fall 2007', 'Summer 1983', 'Fall 1975', 'Spring 1977',
#        'Fall 1983', 'Spring 1975', 'Winter 2008', 'Winter 1980',
#        'Spring 1983', 'Winter 1974', 'Fall 1987', 'Summer 1990',
#        'Summer 1972', 'Winter 1982', 'Spring 1970', 'Fall 1972',
#        'Fall 1969', 'Summer 1981', 'Winter 1981', 'Winter 1985',
#        'Winter 1978', 'Winter 1975', 'Winter 1988', 'Fall 1966',
#        'Winter 1972', 'Winter 1977', 'Winter 1984', 'Fall 1963',
#        'Winter 1967', 'Spring 1972', 'Winter 1963', 'Fall 1976',
#        'Summer 1992', 'Spring 1974', 'Spring 2008', 'Spring 1968',
#        'Summer 1988', 'Winter 1969', 'Summer 1978', 'Fall 2009',
#        'Fall 2008', 'Summer 2008', 'Spring 2009', 'Summer 1986',
#        'Winter 1971', 'Winter 2009', 'Fall 1990', 'Spring 1971',
#        'Fall 1970', 'Fall 1968', 'Spring 2010', 'Spring 1969',
#        'Summer 2009', 'Winter 2010', 'Summer 1976', 'Summer 2010',
#        'Winter 1968', 'Summer 1979', 'Fall 2010', 'Fall 2011',
#        'Spring 2011', 'Winter 2011', 'Summer 2011', 'Spring 1965',
#        'Spring 2012', 'Summer 1989', 'Fall 1967', 'Winter 2012',
#        'Spring 1966', 'Fall 2013', 'Summer 1974', 'Spring 1964',
#        'Winter 1966', 'Summer 2012', 'Fall 2012', 'Summer 2013',
#        'Spring 2013', 'Winter 1964', 'Summer 1966', 'Winter 1965',
#        'Summer 1964', 'Winter 2013', 'Spring 1961', 'Summer 1962',
#        'Winter 2014', 'Summer 1967', 'Winter 2015', 'Fall 2014',
#        'Spring 2015', 'Spring 2014', 'Summer 2014', 'Summer 2015',
#        'Summer 2018', 'Summer 1970', 'Fall 2015', 'Spring 2017',
#        'Winter 2016', 'Spring 2016', 'Winter 2017', 'Summer 2016',
#        'Fall 2016', 'Spring 2018', 'Fall 2017', 'Winter 2019',
#        'Summer 2019', 'Summer 2017', 'Winter 2021', 'Winter 2018',
#        'Spring 2019', 'Winter 2020', 'Fall 2018', 'Fall 2019',
#        'Summer 2020', 'Fall 2020', 'Spring 2020'], dtype=object)

# %% [markdown]
# ><span style="font-size: 20px; color:#839192">En la columna Premiered hay algunos valores unknowns y tambien todos tienen el año de salida y para analizar asi puede ser un poco complicado</span>
# >
# ><span style="font-size: 20px; color:#839192">Primero voy a quitar el año de las estaciones del año por que eso no me interesa analizarlo ya que algunos tienen año y otros no:</span>

# %%
# CREAR UNA NUEVA COLUMNA CON AÑO
anime_EDA["Year season"]= anime_EDA["Premiered"].str.split().str[1]

# %%
# CREAR UNA COLUMNA CON LA ESTACION DEL AÑO LLAMADA SEASON
anime_EDA["Season"]= anime_EDA["Premiered"].str.split().str[0]

# %%
# BORRAR LA COLUMNA PREMIERED
anime_EDA= anime_EDA.drop(columns=["Premiered"])

# %%
#AHORA VOY A COLOCAR EN LA POSICION 9 DONDE ESTABA PREMIERE A SEASON PARA QUE NO ESTE AL FINAL DE DATAFRAME
season= anime_EDA.pop("Season")
anime_EDA.insert(9, "Season", season)

# %%
# LO MISMO CON YEAR SEASON
año= anime_EDA.pop("Year season")
anime_EDA.insert(10, "Year season", año)

# %%
anime_EDA.head(3)
# Out:
#    anime_id                             Name  Score  \
# 0         1                     Cowboy Bebop   8.78
# 1         5  Cowboy Bebop: Tengoku no Tobira   8.39
# 2         6                           Trigun   8.24
#
#                                               Genres            English name  \
# 0    Action, Adventure, Comedy, Drama, Sci-Fi, Space            Cowboy Bebop
# 1              Action, Drama, Mystery, Sci-Fi, Space  Cowboy Bebop:The Movie
# 2  Action, Sci-Fi, Adventure, Comedy, Drama, Shounen                  Trigun
#
#     Japanese name   Type Month Aired Year Aired   Season  ...    Source  \
# 0       カウボーイビバップ     TV         Apr       1998   Spring  ...  Original
# 1  カウボーイビバップ 天国の扉  Movie         Sep       2001  Unknown  ...  Original
# 2           トライガン     TV         Apr       1998   Spring  ...     Manga
#
#           Duration                          Rating Popularity  Members  \
# 0  24 min. per ep.  R - 17+ (violence & profanity)         39  1251960
# 1    1 hr. 55 min.  R - 17+ (violence & profanity)        518   273145
# 2  24 min. per ep.       PG-13 - Teens 13 or older        201   558913
#
#   Favorites Watching Completed  On-Hold  Dropped
# 0     61971   105808    718161    71513    26678
# 1      1174     4143    208333     1935      770
# 2     12944    29113    343492    25465    13925
#
# [3 rows x 25 columns]

# %% [markdown]
#      HE VISTO QUE HA FUNCIONADO PERO HAY UNOS VALOR NAN EN LA COLUMNA AÑOS QUE INTENTARE ARREGLAR MAS ADELANTE

# %% [markdown]
# ><span style="font-size: 20px; color:#839192">Y ahora voy a hacer una funcion lambda para que segun el mes de lanzamiento me ponga en la columna premiered la estacion del año que le corresponde y quitar los unknowns:</span>

# %%
# VER CUANTOS UNKNOWN HAY EN LA COLUMNA
anime_EDA["Season"].isin(["Unknown"]).sum()
# Out:
# 8810

# %%
#MAPEAR LOS MESES A ESTACIONES DEL AÑO
estaciones={"Dec": "Winter",
              "Jan": "Winter",
              "Feb":"Winter",
              "Mar":"Spring" ,
              "Apr" :"Spring",
              "May":"Spring" ,
              "Jun": "Summer",
              "Jul" :"Summer",
              "Aug": "Summer",
              "Sep":"Fall",
              "Oct":"Fall" ,
              "Nov": "Fall"}

# CON ESTE REEMPLAZO LOS UNKNOWS POR LAS ESTACIONES
vdesconocidos= lambda row: estaciones.get(row["Month Aired"],row["Season"])
anime_EDA["Season"]= anime_EDA.apply(vdesconocidos, axis=1)

# %%
#COMPROBAR SI SE HAN CAMBIADO
anime_EDA["Season"].unique()
# Out:
# array(['Spring', 'Fall', 'Summer', 'Winter', 'Unknown'], dtype=object)

# %%
# VER CUANTOS UNKNOWN HAN QUEDADO EN LA COLUMNA
anime_EDA["Season"].isin(["Unknown"]).sum()
# Out:
# 623

# %%
season= anime_EDA["Season"].value_counts()

sns.set(style="whitegrid")
plt.figure(figsize=(8,5))
sns.barplot(x=season.index, y=season.values, hue=season.index, palette="pink")
plt.title("Cuantos animes han salido en distintas estaciones del año", color= "Grey", fontsize =17)
plt.xlabel("Estaciones del Año", color="Grey", fontsize= 10)
plt.tick_params(axis="x", colors="grey")
plt.tick_params(axis="y", colors="grey")

# ES PARA PONER EL PORCENTAJE ARRIBA DE CADA COLUMNAA
for i, value in enumerate(season.values):
    porcentaje =(value / season.sum())* 100
    plt.text(i, value+0.1, f"{porcentaje:.1f}%", ha="center",va="bottom", color="grey")

plt.show()

# %% [markdown]
# ><span style="font-size: 25px; color:#839192">En esta columna podemos ver que en primavera y otoño suelen salir mas animes pero no hay mucha diferencia del resto. igualmente luego se vera si esta relacionado la estacion del año con la popularidad del anime</span>

# %% [markdown]
# ##### Nan y unknowns de la columna Year Aired y year season

# %% [markdown]
# ><span style="font-size: 20px; color:#839192">En la columna anterior he visto que year season tiene valores nan y unknowns y en la year aired tiene tambien valores unknowns asi que  el año que este con unknowns en year aired le voy a poner el año que tenga year season:</span>

# %%
anime_EDA["Year Aired"].unique()
# Out:
# array(['1998', '2001', '2002', '2004', '2005', '1999', '2003', '1995',
#        '1997', '1996', '1988', '1993', '2000', '1979', '1989', '1991',
#        '1985', '1986', '1994', '1992', '1990', '1978', '1973', '2006',
#        '1987', '1984', '1982', '1977', '1983', '1980', '1976', '1968',
#        '1981', 'Unknown', '2007', '1971', '1967', '1975', '1962', '1965',
#        '1969', '1974', '1964', '2008', '1972', '1970', '1966', '1963',
#        '1945', '2009', '2012', '1933', '1943', '2010', '1931', '1932',
#        '1934', '1960', '1958', '2011', '1959', '1947', '1929', '1917',
#        '1930', '1936', '1935', '1938', '1957', '1918', '1927', '1928',
#        '1937', '1940', '1944', '1955', '1956', '1961', '2016', '2013',
#        '2019', '1941', '2014', '2015', '2017', '2018', '1942', '1926',
#        '1948', '2021', '2020'], dtype=object)

# %%
# VER CUANTOS UNKNOWN TIENE LA COLUMNA 
anime_EDA["Year Aired"].isin(["Unknown"]).sum()
# Out:
# 934

# %%
# AQUI QUIERO REEMPLAZAR LOS VALORES UNKNOWN DE LA COLUMNA YEAR AIRED CON LOS VALORES QUE NO SON UNKNOWNS DE LA COLUMNA YEAR SEASON CON UN COMBINE_FIRST()
anime_EDA["Year Aired"] =anime_EDA["Year Aired"].replace("Unknown",pd.NA).combine_first(anime_EDA["Year season"]) #EL COMBINE ES PATA COMBINAR DOS SERIES

# %%
# BORRAR LA COLUMNA YEAR SEASON
anime_EDA= anime_EDA.drop(columns=["Year season"])

# %%
anime_EDA.head(4)
# Out:
#    anime_id                             Name  Score  \
# 0         1                     Cowboy Bebop   8.78
# 1         5  Cowboy Bebop: Tengoku no Tobira   8.39
# 2         6                           Trigun   8.24
# 3         7               Witch Hunter Robin   7.27
#
#                                               Genres            English name  \
# 0    Action, Adventure, Comedy, Drama, Sci-Fi, Space            Cowboy Bebop
# 1              Action, Drama, Mystery, Sci-Fi, Space  Cowboy Bebop:The Movie
# 2  Action, Sci-Fi, Adventure, Comedy, Drama, Shounen                  Trigun
# 3  Action, Mystery, Police, Supernatural, Drama, ...      Witch Hunter Robin
#
#                       Japanese name   Type Month Aired Year Aired  Season  \
# 0                         カウボーイビバップ     TV         Apr       1998  Spring
# 1                    カウボーイビバップ 天国の扉  Movie         Sep       2001    Fall
# 2                             トライガン     TV         Apr       1998  Spring
# 3  Witch Hunter ROBIN (ウイッチハンターロビン)     TV         Jul       2002  Summer
#
#    ...    Source         Duration                          Rating Popularity  \
# 0  ...  Original  24 min. per ep.  R - 17+ (violence & profanity)         39
# 1  ...  Original    1 hr. 55 min.  R - 17+ (violence & profanity)        518
# 2  ...     Manga  24 min. per ep.       PG-13 - Teens 13 or older        201
# 3  ...  Original  25 min. per ep.       PG-13 - Teens 13 or older       1467
#
#    Members Favorites Watching  Completed  On-Hold  Dropped
# 0  1251960     61971   105808     718161    71513    26678
# 1   273145      1174     4143     208333     1935      770
# 2   558913     12944    29113     343492    25465    13925
# 3    94683       587     4300      46165     5121     5378
#
# [4 rows x 24 columns]

# %%
#COMPRUEBO LAS FILAS NAN Y SI, ME HE QUITADO ALGUNAS
anime_EDA["Year Aired"].isna().sum()
# Out:
# 927

# %%
# VUELVO A RENOMBRAR LOS NAN CON VALORES OTROS
anime_EDA["Year Aired"]= anime_EDA["Year Aired"].fillna("Others")

# %%
# Y COMPRUEBO
anime_EDA.isna().sum()
# Out:
# anime_id         0
# Name             0
# Score            0
# Genres           0
# English name     0
# Japanese name    0
# Type             0
# Month Aired      0
# Year Aired       0
# Season           0
# Episodes         0
# Producers        0
# Licensors        0
# Studios          0
# Source           0
# Duration         0
# Rating           0
# Popularity       0
# Members          0
# Favorites        0
# Watching         0
# Completed        0
# On-Hold          0
# Dropped          0
# dtype: int64

# %% [markdown]
# ##### Columna generos

# %%
# VER EL CONTENIDO DE LA COLUMNA GENEROS CON .UNIQUE()
anime_EDA["Genres"].unique()
# Out:
# array(['Action, Adventure, Comedy, Drama, Sci-Fi, Space',
#        'Action, Drama, Mystery, Sci-Fi, Space',
#        'Action, Sci-Fi, Adventure, Comedy, Drama, Shounen', ...,
#        'Action, Cars, Sports', 'Mystery, Supernatural, School',
#        'Mystery, Psychological, Supernatural, Thriller, Shounen'],
#       dtype=object)

# %% [markdown]
# ><span style="font-size: 20px; color:#839192">En la columna generos he visto que la mayoria de generos
# >     en cada fila vienen en listas.</span>
# >
# ><span style="font-size: 20px; color:#839192">PAsi que voy a separarlos haciendo un split y un dummy para crear un nuevo dataframe de generos:</span>

# %%
#HAGO UNA FUNCION LAMBDA CON SPLIT PARA SEPARAR LOS GENEROS DE UNA LISTA DE GENEROS POR COMAS

anime_EDA["Genres"]= anime_EDA["Genres"].apply(lambda x: x.split(", "))

# %%
# EL GET DUMMIES PARA CREAR COLUMNAS PARA CADA GENERO QUE HE SEPARADO DE LA COLUMNA GENRES, EL .APPLY() Y .STACK PARA CONVERTIER LAS COLUMNAS EN INDICES MULTIPLES
# EL GROUPBY.MAX AGRUPAR LAS FILAS POR NIVEL 0 Y TOMA EL VALOR MAXIMO PARA CADA
generos=pd.get_dummies(anime_EDA["Genres"].apply(pd.Series).stack()).groupby(level=0).max()

# %%
generos
# Out:
#        Action  Adventure   Cars  Comedy  Dementia  Demons  Drama  Ecchi  \
# 0        True       True  False    True     False   False   True  False
# 1        True      False  False   False     False   False   True  False
# 2        True       True  False    True     False   False   True  False
# 3        True      False  False   False     False   False   True  False
# 4       False       True  False   False     False   False  False  False
# ...       ...        ...    ...     ...       ...     ...    ...    ...
# 14916   False      False  False   False     False   False  False  False
# 14917   False      False  False    True     False   False  False  False
# 14918   False      False  False   False     False   False  False  False
# 14924   False      False  False   False     False   False  False  False
# 14943   False      False  False    True     False   False  False  False
#
#        Fantasy   Game  ...  Shounen  Shounen Ai  Slice of Life  Space  Sports  \
# 0        False  False  ...    False       False          False   True   False
# 1        False  False  ...    False       False          False   True   False
# 2        False  False  ...     True       False          False  False   False
# 3        False  False  ...    False       False          False  False   False
# 4         True  False  ...     True       False          False  False   False
# ...        ...    ...  ...      ...         ...            ...    ...     ...
# 14916    False  False  ...    False        True          False  False   False
# 14917    False  False  ...    False       False           True  False   False
# 14918    False  False  ...     True       False          False  False   False
# 14924     True  False  ...    False       False          False  False   False
# 14943    False  False  ...    False       False          False  False    True
#
#        Super Power  Supernatural  Thriller  Unknown  Vampire
# 0            False         False     False    False    False
# 1            False         False     False    False    False
# 2            False         False     False    False    False
# 3            False          True     False    False    False
# 4            False          True     False    False    False
# ...            ...           ...       ...      ...      ...
# 14916        False         False     False    False    False
# 14917        False         False     False    False    False
# 14918        False          True      True    False    False
# 14924        False         False     False    False    False
# 14943        False         False     False    False    False
#
# [13231 rows x 41 columns]

# %%
# RENOMBRAR LA COLUMNA UNKNOWN POR OTHER
generos.rename(columns={"Unknown":"Others"}, inplace=True)

# %%
grafico_gen= generos.sum().sort_values(ascending= False)

plt.figure(figsize=(7,8))
sns.set_style("darkgrid")
ax = sns.barplot(x=grafico_gen.values, y=grafico_gen.index, hue=grafico_gen.index, palette="viridis", dodge=False)
plt.title("Géneros de Anime", color="Grey", fontsize=25)
plt.xlabel("Número de Animes", color= "Grey", fontsize=15)
plt.ylabel("Géneros",color = "Grey", fontsize =15)
plt.tick_params(axis="x", colors="grey")
plt.tick_params(axis="y", colors="grey")

plt.tight_layout()
plt.show()

# %% [markdown]
# ><span style="font-size: 25px; color:#839192 " >En esta grafica podemos ver que los generos mas comunes son comedia, accion, aventura, fantasia, ciencia ficcion y drama</span>

# %% [markdown]
# ##### Columna Rating:

# %%
anime_EDA["Rating"].unique()
# Out:
# array(['R - 17+ (violence & profanity)', 'PG-13 - Teens 13 or older',
#        'PG - Children', 'R+ - Mild Nudity', 'G - All Ages', 'Unknown'],
#       dtype=object)

# %% [markdown]
# ><span style="font-size: 20px; color:#839192">En la columna Rating mas de lo mismo, va a ser poco visual analizarlo como esta</span>
# >
# ><span style="font-size: 20px; color:#839192">Voy a hacer un regex para separar la R, PG, G y que solo se vea la columna con esos. Despues voy a quitar los unknowns sacando el valor mas comun del rating por genero:</span>

# %%
#SEPARAR LA R, PG, R+ Y G DEL RESTO DEL VALOR DE RATING 
anime_EDA["Rating"]= anime_EDA["Rating"].str.extract(r"(R|PG|G|)")

# %%
anime_EDA["Rating"].unique()
# Out:
# array(['R', 'PG', 'G', ''], dtype=object)

# %%
# RENOMBRAR A LOS NAN COMO ESTABAN POR Others
anime_EDA["Rating"] = anime_EDA["Rating"].replace("", "Others")

# %%
anime_EDA["Rating"].unique()
# Out:
# array(['R', 'PG', 'G', 'Others'], dtype=object)

# %% [markdown]
# ><span style="font-size: 20px; color:#839192">Quitar los Others sacando el valor mas comun del rating por genero </span>

# %%
# QUIERO SACAR EL RATING PREDOMINANTE POR GENERO.
# ASI QUE CON LA MODA VOY A SACAR EL VALOR MAS COMUN DEL RATING POR GENERO PARA QUITAR OTHERS
generos_edades={}

for g in generos.columns:
    filas_g= anime_EDA[generos[g]==1] 
    moda_r=filas_g["Rating"].mode().iloc[0] if not filas_g.empty else "Others"
    generos_edades[g]=moda_r

# %%
# AQUI PONGO EL RATING MAS COMUN QUE HE SACADO POR GENERO EN LA COLUMNA 
for index, f in anime_EDA.iterrows():
    if f["Rating"]=="Others":
        genres_fila= generos.loc[index, generos.columns]
        rating= genres_fila.idxmax()
        resultado= generos_edades.get(rating,"Others")
        anime_EDA.at[index,"Rating"]= resultado

# %%
anime_EDA["Rating"].unique()
# Out:
# array(['R', 'PG', 'G'], dtype=object)

# %%
# VER CUANTOS OTHERS HAY EN LA COLUMNA
anime_EDA["Rating"].isin(["Others"]).sum()
# Out:
# 0

# %%
edades =anime_EDA["Rating"].value_counts()

plt.figure(figsize=(6,6), facecolor="None")
plt.pie(edades, startangle=100, colors=sns.color_palette("Paired"), autopct="%1.1f%%")
plt.title("CLASIFICACION POR EDADES PERMITIDAS EN ANIMES", color="#D0D3D4", fontsize=17)
plt.legend(labels=edades.index, title="Ratings",bbox_to_anchor=(1.0,0.5), loc="center")

texto= "PG- PARA NIÑOS MENORES DE 13 AÑOS\n\nR- RESTRINGIDO A MENORES DE 17 AÑOS\n\nG- TODOS LOS PUBLICOS"
plt.text(-1.9, -1.2, texto, fontsize=10,va="center", ha="left", color="white")

plt.show()

# %% [markdown]
# ><span style="font-size: 25px; color:#839192">Aqui podemos ver que el rating de edad del 57% de los animes esta dirigido para niños</span>

# %% [markdown]
# ##### Columna duration:

# %%
anime_EDA["Duration"].unique()
# Out:
# array(['24 min. per ep.', '1 hr. 55 min.', '25 min. per ep.',
#        '23 min. per ep.', '27 min. per ep.', '24 min.', '22 min. per ep.',
#        '1 hr. 44 min.', '1 hr. 27 min.', '1 hr. 22 min.',
#        '30 min. per ep.', '1 hr. 31 min.', '2 hr. 4 min.',
#        '1 hr. 45 min.', '52 min.', '1 hr. 59 min.', '2 hr.',
#        '21 min. per ep.', '14 min. per ep.', '12 min. per ep.',
#        '34 min. per ep.', '46 min. per ep.', '1 hr. 37 min.',
#        '20 min. per ep.', '2 hr. 15 min.', '26 min. per ep.',
#        '28 min. per ep.', '21 min.', '46 min.', '15 min. per ep.',
#        '2 hr. 5 min.', '29 min. per ep.', '33 min. per ep.',
#        '1 hr. 24 min.', '48 min.', '1 hr. 19 min.', '25 min.',
#        '1 hr. 30 min.', '1 hr. 1 min.', '4 min. per ep.',
#        '7 min. per ep.', '1 hr. 46 min.', '18 min. per ep.',
#        '1 hr. 41 min.', '11 min. per ep.', '13 min. per ep.', '55 min.',
#        '1 hr. 21 min.', '1 hr. 2 min.', '37 min. per ep.',
#        '42 min. per ep.', '37 min.', '19 min.', '1 hr. 33 min.',
#        '1 hr. 14 min.', '50 min.', '42 min.', '1 hr. 20 min.',
#        '45 min. per ep.', '1 hr. 39 min.', '1 hr. 38 min.', '26 min.',
#        '1 hr. 35 min.', '1 hr. 34 min.', '28 min.', '39 min. per ep.',
#        '40 min.', '5 min. per ep.', '1 hr. 32 min.', '2 hr. 12 min.',
#        '1 hr. 36 min.', '36 min. per ep.', '30 min.', '1 hr. 49 min.',
#        '1 hr. 26 min.', '1 hr. 25 min.', '1 hr. 6 min.', '1 hr. 42 min.',
#        '1 hr. 43 min.', '1 hr. 23 min.', '15 min.', '51 min.',
#        '31 min. per ep.', '2 hr. 6 min.', '1 hr. 57 min.',
#        '1 hr. 28 min.', '8 min. per ep.', '1 hr. 51 min.', '22 min.',
#        '6 min.', '1 hr. 15 min.', '32 min.', '6 min. per ep.', '23 min.',
#        '1 hr. 17 min.', '35 min. per ep.', '1 min. per ep.',
#        '3 min. per ep.', '20 min.', '10 min.', '2 hr. 20 min.',
#        '16 min. per ep.', '31 min.', '1 hr. 7 min.', '1 hr. 12 min.',
#        '27 min.', '17 min.', '29 min.', '50 min. per ep.',
#        '1 hr. 40 min.', '48 min. per ep.', '1 hr.', '35 min.',
#        '1 hr. 5 min.', '49 min.', '17 min. per ep.', '10 min. per ep.',
#        '33 min.', '43 min. per ep.', '59 min.', '9 min. per ep.',
#        '1 hr. 11 min.', '45 min.', '41 min.', '1 hr. 10 min.', '11 min.',
#        '53 min.', '32 min. per ep.', '5 min.', '47 min.', '44 min.',
#        '4 min.', '1 hr. 58 min.', '2 hr. 1 min.', '1 hr. 3 min.',
#        '40 min. per ep.', '1 hr. 48 min.', '1 hr. 18 min.',
#        '47 min. per ep.', '2 hr. 16 min.', '43 min.', '52 min. per ep.',
#        '54 min.', '56 min.', '58 min.', '2 hr. 19 min.',
#        '51 min. per ep.', '2 hr. 8 min.', '2 hr. 10 min.',
#        '41 min. per ep.', '58 min. per ep.', '1 hr. 50 min.',
#        '1 hr. 47 min.', '12 min.', '1 hr. 13 min.', '54 min. per ep.',
#        '38 min. per ep.', '1 hr. 5 min. per ep.', '39 min.',
#        '1 hr. 9 min.', '1 hr. per ep.', '3 min.', '2 hr. 11 min.',
#        '57 min.', '1 hr. 52 min.', '2 min. per ep.', '16 min.', '13 min.',
#        '38 min.', '1 hr. 17 min. per ep.', '8 min.',
#        '1 hr. 38 min. per ep.', '1 hr. 7 min. per ep.', '55 min. per ep.',
#        '1 hr. 29 min.', '1 hr. 56 min.', '53 min. per ep.', '1 min.',
#        '9 min.', '7 min.', '1 hr. 35 min. per ep.',
#        '1 hr. 30 min. per ep.', '49 min. per ep.', '2 hr. 41 min.',
#        '2 hr. 40 min.', '14 min.', '1 hr. 8 min.', '57 min. per ep.',
#        '2 min.', '18 min.', '2 hr. 21 min.', '2 hr. 33 min.',
#        '1 hr. 52 min. per ep.', '1 hr. 4 min.', '2 hr. 32 min.',
#        '2 hr. 30 min.', '2 hr. 43 min.', '2 hr. 2 min.', '36 min.',
#        '1 hr. 53 min.', '34 min.', '1 hr. 16 min.', '1 hr. 54 min.',
#        '44 min. per ep.', '12 sec.', '19 min. per ep.', '52 sec.',
#        '30 sec. per ep.', '1 hr. 2 min. per ep.', '22 sec. per ep.',
#        '2 hr. 3 min.', '40 sec. per ep.', '2 hr. 42 min.', '32 sec.',
#        '1 hr. 14 min. per ep.', '39 sec. per ep.', '2 hr. 28 min.',
#        '2 hr. 27 min.', '2 hr. 7 min.', 'Unknown', '15 sec. per ep.',
#        '30 sec.', '1 hr. 11 min. per ep.', '1 hr. 16 min. per ep.',
#        '53 sec. per ep.', '38 sec.', '29 sec.', '35 sec.',
#        '33 sec. per ep.', '2 hr. 36 min.', '34 sec. per ep.',
#        '2 hr. 17 min.', '1 hr. 15 min. per ep.', '24 sec. per ep.',
#        '37 sec. per ep.', '31 sec. per ep.', '29 sec. per ep.',
#        '1 hr. 36 min. per ep.', '31 sec.', '41 sec.', '45 sec. per ep.',
#        '35 sec. per ep.', '15 sec.', '49 sec. per ep.', '17 sec.',
#        '54 sec.', '2 hr. 14 min.', '16 sec.', '41 sec. per ep.',
#        '27 sec.', '42 sec.', '14 sec.', '26 sec. per ep.', '36 sec.',
#        '37 sec.', '58 sec. per ep.', '50 sec.', '45 sec.', '33 sec.',
#        '32 sec. per ep.', '55 sec.', '57 sec.', '40 sec.', '10 sec.',
#        '46 sec.', '7 sec.', '49 sec.', '39 sec.', '51 sec. per ep.',
#        '57 sec. per ep.', '10 sec. per ep.', '44 sec. per ep.', '3 sec.',
#        '2 hr. 47 min.', '25 sec.', '20 sec. per ep.', '42 sec. per ep.',
#        '19 sec.', '18 sec. per ep.', '28 sec.', '44 sec.',
#        '46 sec. per ep.', '56 sec. per ep.', '34 sec.', '50 sec. per ep.',
#        '58 sec.', '51 sec.', '21 sec.', '13 sec.', '23 sec.', '22 sec.',
#        '21 sec. per ep.', '25 sec. per ep.', '12 sec. per ep.',
#        '38 sec. per ep.', '14 sec. per ep.', '1 hr. 9 min. per ep.',
#        '36 sec. per ep.', '20 sec.', '1 hr. 27 min. per ep.',
#        '55 sec. per ep.'], dtype=object)

# %% [markdown]
# ><span style="font-size: 20px; color:#839192">En la columna duracion hay peliculas, series etc. Por lo tanto cuando voy a visualizarlo se hace casi imposible</span>
# >
# ><span style="font-size: 20px; color:#839192">Quiero convertir todas las duraciones en minutos para luego poder analizarlo mejor:</span>

# %%
#PASAR TODAS LAS HORAS A MINUTOS 
min= r"(\d+)\s*(hr|min|sec)"

def minutos(duracion):
    total_min=0
    for min in duracion:
        value, unit= min
        value = int(value)
        if unit== "hr":
            total_min +=value*60
        elif unit == "min":
            total_min +=value
        elif unit== "sec":
            total_min+= value/60
    return round(total_min)

anime_EDA["Duracion"]= anime_EDA["Duration"].str.findall(min).apply(minutos) 
#STR.FINDALL ES PARA BUSCAR TODAS LOS PATRONES. POR EJEMPO SI ESTAN EL HR PASA A 60 MINUTOS ETC

# %%
#COLOCAR LA COLUMNA DURATION EN LA POSICION QUE ESTABA
anime_EDA.drop(columns=["Duration"], inplace=True)

duracion= anime_EDA.pop("Duracion")
anime_EDA.insert(11,"Duracion", duracion)

# %%
anime_EDA.head(4)
# Out:
#    anime_id                             Name  Score  \
# 0         1                     Cowboy Bebop   8.78
# 1         5  Cowboy Bebop: Tengoku no Tobira   8.39
# 2         6                           Trigun   8.24
# 3         7               Witch Hunter Robin   7.27
#
#                                               Genres            English name  \
# 0  [Action, Adventure, Comedy, Drama, Sci-Fi, Space]            Cowboy Bebop
# 1            [Action, Drama, Mystery, Sci-Fi, Space]  Cowboy Bebop:The Movie
# 2  [Action, Sci-Fi, Adventure, Comedy, Drama, Sho...                  Trigun
# 3  [Action, Mystery, Police, Supernatural, Drama,...      Witch Hunter Robin
#
#                       Japanese name   Type Month Aired Year Aired  Season  \
# 0                         カウボーイビバップ     TV         Apr       1998  Spring
# 1                    カウボーイビバップ 天国の扉  Movie         Sep       2001    Fall
# 2                             トライガン     TV         Apr       1998  Spring
# 3  Witch Hunter ROBIN (ウイッチハンターロビン)     TV         Jul       2002  Summer
#
#    ...   Studios    Source Rating Popularity  Members Favorites Watching  \
# 0  ...   Sunrise  Original      R         39  1251960     61971   105808
# 1  ...     Bones  Original      R        518   273145      1174     4143
# 2  ...  Madhouse     Manga     PG        201   558913     12944    29113
# 3  ...   Sunrise  Original     PG       1467    94683       587     4300
#
#    Completed  On-Hold  Dropped
# 0     718161    71513    26678
# 1     208333     1935      770
# 2     343492    25465    13925
# 3      46165     5121     5378
#
# [4 rows x 24 columns]

# %%
# VER CUANTOS UNKNOWN HAY EN LA COLUMNA
anime_EDA["Duracion"].isin(["Unknown"]).sum()
# Out:
# 0

# %% [markdown]
# ##### Columna English name:

# %%
anime_EDA["English name"].unique()
# Out:
# array(['Cowboy Bebop', 'Cowboy Bebop:The Movie', 'Trigun', ...,
#        'Cooking with Valkyries Spring Festival Special',
#        'The Promised Neverland Season 2 Episode 5.5',
#        'Immemorial Love For You 2nd Season'], dtype=object)

# %% [markdown]
# ><span style="font-size: 20px; color:#839192">En la columna English name hay algunos valores unknown asi que voy a asignarle a los unknowns el nombre de la columna name:</span>

# %%
#SUSTITUIR LOS VALORES UNKNOWN DE ENGLISH NAME POR EL NOMBRE ORIGINAL
anime_EDA["English name"]= anime_EDA.apply(lambda row:row["Name"] if row["English name"]=="Unknown" else row ["English name"],axis=1)

#AQUI PRIMERO PENSE HACER UN COMBINE COMO EN YEAR SEASON PERO TUVE PROBLEMAS

# %%
anime_EDA.head(4)
# Out:
#    anime_id                             Name  Score  \
# 0         1                     Cowboy Bebop   8.78
# 1         5  Cowboy Bebop: Tengoku no Tobira   8.39
# 2         6                           Trigun   8.24
# 3         7               Witch Hunter Robin   7.27
#
#                                               Genres            English name  \
# 0  [Action, Adventure, Comedy, Drama, Sci-Fi, Space]            Cowboy Bebop
# 1            [Action, Drama, Mystery, Sci-Fi, Space]  Cowboy Bebop:The Movie
# 2  [Action, Sci-Fi, Adventure, Comedy, Drama, Sho...                  Trigun
# 3  [Action, Mystery, Police, Supernatural, Drama,...      Witch Hunter Robin
#
#                       Japanese name   Type Month Aired Year Aired  Season  \
# 0                         カウボーイビバップ     TV         Apr       1998  Spring
# 1                    カウボーイビバップ 天国の扉  Movie         Sep       2001    Fall
# 2                             トライガン     TV         Apr       1998  Spring
# 3  Witch Hunter ROBIN (ウイッチハンターロビン)     TV         Jul       2002  Summer
#
#    ...   Studios    Source Rating Popularity  Members Favorites Watching  \
# 0  ...   Sunrise  Original      R         39  1251960     61971   105808
# 1  ...     Bones  Original      R        518   273145      1174     4143
# 2  ...  Madhouse     Manga     PG        201   558913     12944    29113
# 3  ...   Sunrise  Original     PG       1467    94683       587     4300
#
#    Completed  On-Hold  Dropped
# 0     718161    71513    26678
# 1     208333     1935      770
# 2     343492    25465    13925
# 3      46165     5121     5378
#
# [4 rows x 24 columns]

# %%
# VER CUANTOS UNKNOWN HAY EN LA COLUMNA
anime_EDA["English name"].isin(["Unknown"]).sum()
# Out:
# 0

# %% [markdown]
# ##### Eliminar lo que no me interesa

# %% [markdown]
# ><span style="font-size: 20px; color:#839192">Ahora que ya he rellenado algunos unknowns con la columna producers y licensor voy a borrar las columnas que no me hacen falta</span>

# %%
#BORRAR ESTAS COLUMNAS YA QUE DESDE MI PUNTO DE VISTA SON INNECESARIAS PARA EL ANALISIS QUE VOY A HACER
anime_EDA.drop(["Japanese name","anime_id","Producers", "Licensors","Year Aired", "Studios", "Source"],axis=1, inplace=True)

# %%
#COMPROBAR SI SE HAN ELIMINADO CORRECTAMENTE
anime_EDA.head()
# Out:
#                               Name  Score  \
# 0                     Cowboy Bebop   8.78
# 1  Cowboy Bebop: Tengoku no Tobira   8.39
# 2                           Trigun   8.24
# 3               Witch Hunter Robin   7.27
# 4                   Bouken Ou Beet   6.98
#
#                                               Genres            English name  \
# 0  [Action, Adventure, Comedy, Drama, Sci-Fi, Space]            Cowboy Bebop
# 1            [Action, Drama, Mystery, Sci-Fi, Space]  Cowboy Bebop:The Movie
# 2  [Action, Sci-Fi, Adventure, Comedy, Drama, Sho...                  Trigun
# 3  [Action, Mystery, Police, Supernatural, Drama,...      Witch Hunter Robin
# 4        [Adventure, Fantasy, Shounen, Supernatural]  Beet the Vandel Buster
#
#     Type Month Aired  Season Episodes  Duracion Rating  Popularity  Members  \
# 0     TV         Apr  Spring       26        24      R          39  1251960
# 1  Movie         Sep    Fall        1       115      R         518   273145
# 2     TV         Apr  Spring       26        24     PG         201   558913
# 3     TV         Jul  Summer       26        25     PG        1467    94683
# 4     TV         Sep    Fall       52        23     PG        4369    13224
#
#    Favorites  Watching  Completed  On-Hold  Dropped
# 0      61971    105808     718161    71513    26678
# 1       1174      4143     208333     1935      770
# 2      12944     29113     343492    25465    13925
# 3        587      4300      46165     5121     5378
# 4         18       642       7314      766     1108

# %%
# VER CUANTOS UNKNOWNS QUEDAN
unknowns=(anime_EDA =="Unknown").sum()
unknowns
# Out:
# Name              0
# Score             0
# Genres            0
# English name      0
# Type              0
# Month Aired     625
# Season          623
# Episodes        135
# Duracion          0
# Rating            0
# Popularity        0
# Members           0
# Favorites         0
# Watching          0
# Completed         0
# On-Hold           0
# Dropped           0
# dtype: int64

# %%
# RENOMBRAR TODOS ESOS UNKNOWNS PARA QUE QUEDE VISUALMENTE MEJOR
anime_EDA.replace("Unknown","Other", inplace=True)

# %%
# MIRAR EL TOTAL DE OTHERS - EN EL PRIMER ANALISIS HABIA 45783
unknowns= (anime_EDA =="Other").sum().sum()
unknowns
# Out:
# 1383

# %% [markdown]
# ## <span style="color:#85929E "> GUARDAR BASE DE DATOS </span>

# %%
#Guardar base de datos limpia
ruta= "./data/anime-EDA.csv"
anime_EDA.to_csv(ruta, index=False, encoding="utf-8")

# %% [markdown]
# ## <span style="color:#85929E "> ANALISIS EXPLORATORIO </span>

# %% [markdown]
# ### DATAFRAMES

# %%
# DATAFRAME ANIME
anime_EDA
# Out:
#                                                  Name  Score  \
# 0                                        Cowboy Bebop   8.78
# 1                     Cowboy Bebop: Tengoku no Tobira   8.39
# 2                                              Trigun   8.24
# 3                                  Witch Hunter Robin   7.27
# 4                                      Bouken Ou Beet   6.98
# ...                                               ...    ...
# 14916    Kuro Gal ni Natta kara Shinyuu to shitemita.   6.51
# 14917    Nu Wushen de Canzhuo Spring Festival Special   6.83
# 14918  Yakusoku no Neverland 2nd Season: Michishirube   4.81
# 14924                  Ai Zai Xi Yuan Qian 2nd Season   6.51
# 14943                             SK∞: Crazy Rock Jam   6.52
#
#                                                   Genres  \
# 0      [Action, Adventure, Comedy, Drama, Sci-Fi, Space]
# 1                [Action, Drama, Mystery, Sci-Fi, Space]
# 2      [Action, Sci-Fi, Adventure, Comedy, Drama, Sho...
# 3      [Action, Mystery, Police, Supernatural, Drama,...
# 4            [Adventure, Fantasy, Shounen, Supernatural]
# ...                                                  ...
# 14916                              [Romance, Shounen Ai]
# 14917                            [Slice of Life, Comedy]
# 14918  [Mystery, Psychological, Supernatural, Thrille...
# 14924                                 [Fantasy, Romance]
# 14943                                   [Comedy, Sports]
#
#                                          English name     Type Month Aired  \
# 0                                        Cowboy Bebop       TV         Apr
# 1                              Cowboy Bebop:The Movie    Movie         Sep
# 2                                              Trigun       TV         Apr
# 3                                  Witch Hunter Robin       TV         Jul
# 4                              Beet the Vandel Buster       TV         Sep
# ...                                               ...      ...         ...
# 14916    Kuro Gal ni Natta kara Shinyuu to shitemita.       TV         Feb
# 14917  Cooking with Valkyries Spring Festival Special  Special         Feb
# 14918     The Promised Neverland Season 2 Episode 5.5  Special         Feb
# 14924              Immemorial Love For You 2nd Season      ONA         Feb
# 14943                             SK∞: Crazy Rock Jam  Special         Mar
#
#        Season Episodes  Duracion Rating  Popularity  Members  Favorites  \
# 0      Spring       26        24      R          39  1251960      61971
# 1        Fall        1       115      R         518   273145       1174
# 2      Spring       26        24     PG         201   558913      12944
# 3      Summer       26        25     PG        1467    94683        587
# 4        Fall       52        23     PG        4369    13224         18
# ...       ...      ...       ...    ...         ...      ...        ...
# 14916  Winter    Other         4      R        7387     3636         90
# 14917  Winter        1        10     PG       11973      540          8
# 14918  Winter        1        23      R        4398    13070         90
# 14924  Winter       16         0     PG       12411      463         35
# 14943  Spring        1        23     PG        4830    10722        167
#
#        Watching  Completed  On-Hold  Dropped
# 0        105808     718161    71513    26678
# 1          4143     208333     1935      770
# 2         29113     343492    25465    13925
# 3          4300      46165     5121     5378
# 4           642       7314      766     1108
# ...         ...        ...      ...      ...
# 14916       768          3       79       35
# 14917        51        168       18        2
# 14918      1183       8196      119      202
# 14924        40          0        7        7
# 14943       739       7207       57       45
#
# [13231 rows x 17 columns]

# %% [markdown]
#  SIGNIFICADO DE LAS COLUMNAS
# | <!-- -->      | <!-- -->        |
# |:-------------:|:---------------:|
# | **Name**| *Nombre del anime*|
# | **Score** | *Puntuación media del anime* |
# | **Genres** | *Generos del anime* |
# | **English name** | *Nombre del anime en ingles* |
# | **Type** | *Tipo de anime. serie, película u OVA* |
# | **Episodes** | *Episodios del anime* |
# | **Month Aired** | *Meses en los que se emitió el anime* |
# | **Season** | *La temporada y año en que se estrenó el anime* |
# | **Duration** | *La duración de cada episodio* |
# | **Rating** | *La edad recomendada* |
# | **Popularity** | *la popularidad del anime* |
# | **Members** | *La cantidad de personas que tienen el anime en su lista* |
# | **Favorites** | *La cantidad de personas que han marcado el anime como favorito* |
# | **Watching** | *La cantidad de personas que actualmente ven el anime* |
# | **Completed** | *La cantidad de personas que han completado la visualización del anime.* |
# | **On-Hold** | *La cantidad de usuarion que estan a la espera de ver un anime* |
# | **Dropped** | *La cantidad de usuarios que han abandonado el anime* |

# %%
# DATAFRAME GENEROS
generos
# Out:
#        Action  Adventure   Cars  Comedy  Dementia  Demons  Drama  Ecchi  \
# 0        True       True  False    True     False   False   True  False
# 1        True      False  False   False     False   False   True  False
# 2        True       True  False    True     False   False   True  False
# 3        True      False  False   False     False   False   True  False
# 4       False       True  False   False     False   False  False  False
# ...       ...        ...    ...     ...       ...     ...    ...    ...
# 14916   False      False  False   False     False   False  False  False
# 14917   False      False  False    True     False   False  False  False
# 14918   False      False  False   False     False   False  False  False
# 14924   False      False  False   False     False   False  False  False
# 14943   False      False  False    True     False   False  False  False
#
#        Fantasy   Game  ...  Shounen  Shounen Ai  Slice of Life  Space  Sports  \
# 0        False  False  ...    False       False          False   True   False
# 1        False  False  ...    False       False          False   True   False
# 2        False  False  ...     True       False          False  False   False
# 3        False  False  ...    False       False          False  False   False
# 4         True  False  ...     True       False          False  False   False
# ...        ...    ...  ...      ...         ...            ...    ...     ...
# 14916    False  False  ...    False        True          False  False   False
# 14917    False  False  ...    False       False           True  False   False
# 14918    False  False  ...     True       False          False  False   False
# 14924     True  False  ...    False       False          False  False   False
# 14943    False  False  ...    False       False          False  False    True
#
#        Super Power  Supernatural  Thriller  Others  Vampire
# 0            False         False     False   False    False
# 1            False         False     False   False    False
# 2            False         False     False   False    False
# 3            False          True     False   False    False
# 4            False          True     False   False    False
# ...            ...           ...       ...     ...      ...
# 14916        False         False     False   False    False
# 14917        False         False     False   False    False
# 14918        False          True      True   False    False
# 14924        False         False     False   False    False
# 14943        False         False     False   False    False
#
# [13231 rows x 41 columns]

# %%
# DATAFRAME VARIABLES NUMERICAS
anime_num= anime_EDA.select_dtypes(include=["number"])
anime_num
# Out:
#        Score  Duracion  Popularity  Members  Favorites  Watching  Completed  \
# 0       8.78        24          39  1251960      61971    105808     718161
# 1       8.39       115         518   273145       1174      4143     208333
# 2       8.24        24         201   558913      12944     29113     343492
# 3       7.27        25        1467    94683        587      4300      46165
# 4       6.98        23        4369    13224         18       642       7314
# ...      ...       ...         ...      ...        ...       ...        ...
# 14916   6.51         4        7387     3636         90       768          3
# 14917   6.83        10       11973      540          8        51        168
# 14918   4.81        23        4398    13070         90      1183       8196
# 14924   6.51         0       12411      463         35        40          0
# 14943   6.52        23        4830    10722        167       739       7207
#
#        On-Hold  Dropped
# 0        71513    26678
# 1         1935      770
# 2        25465    13925
# 3         5121     5378
# 4          766     1108
# ...        ...      ...
# 14916       79       35
# 14917       18        2
# 14918      119      202
# 14924        7        7
# 14943       57       45
#
# [13231 rows x 9 columns]

# %% [markdown]
# #### INFORMACION GENERAL DE LA BASE DE DATOS

# %%
#INFORMACION
anime_EDA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13231 entries, 0 to 14943
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          13231 non-null  object
#  1   Score         13231 non-null  float64
#  2   Genres        13231 non-null  object
#  3   English name  13231 non-null  object
#  4   Type          13231 non-null  object
#  5   Month Aired   13231 non-null  object
#  6   Season        13231 non-null  object
#  7   Episodes      13231 non-null  object
#  8   Duracion      13231 non-null  int64
#  9   Rating        13231 non-null  object
#  10  Popularity    13231 non-null  int64
#  11  Members       13231 non-null  int64
#  12  Favorites     13231 non-null  int64
#  13  Watching      13231 non-null  int64
#  14  Completed     13231 non-null  int64
#  15  On-Hold       13231 non-null  int64
#  16  Dropped       13231 non-null  int64
# dtypes: float64(1), int64(8), object(8)
# memory usage: 2.3+ MB

# %%
anime_EDA.isna().sum()
# Out:
# Name            0
# Score           0
# Genres          0
# English name    0
# Type            0
# Month Aired     0
# Season          0
# Episodes        0
# Duracion        0
# Rating          0
# Popularity      0
# Members         0
# Favorites       0
# Watching        0
# Completed       0
# On-Hold         0
# Dropped         0
# dtype: int64

# %%
#VER LAS FILAS Y COLUMNAS QUE TIENE
anime_EDA.shape
# Out:
# (13231, 17)

# %%
# HACER LA CORRELACION DE LOS VALORES NUMERICOS DE DATADRAME
columnas= anime_EDA.select_dtypes(exclude=object).corr().round(2)
sns.heatmap(columnas, annot=True,cmap="YlGn", fmt=".2f", linewidths=.5)
plt.title("CORRELACION")
plt.show()

# %% [markdown]
# #### HIPOTESIS

# %% [markdown]
# ><span style="color:#839192" >1.¿Existe relación entre la puntuación media y la popularidad? </span>
# >
# ><span style="color:#839192" >2.¿Las puntuaciones se puede ver afectada por la duracion del anime?.</span>
# >
# ><span style="color:#839192" >3.¿Los animes estrenados en ciertas estaciones del año pueden tener puntuaciones más altas?</span>
# >
# ><span style="color:#839192" >4.¿El número de espectadores que han completado un anime está positivamente correlacionado con su puntuación?.</span>
# >
# ><span style=" color:#839192" >5. ¿Tiene impacto la duración en la popularidad?</span>
# >
# ><span style="color:#839192" >6.¿Los animes con clasificaciones de edad más altas pueden tener menor popularidad y score, ya que restringen al público potencial?.</span>
# >
# ><span style="color:#839192" >7.¿Hay evidencia para afirmar que la puntuación promedio de las series de anime no es la misma que la media general de todas las puntuaciones de anime?</span>
# >
# ><span style="color:#839192" >8.¿Hay evidencia para afirmar que la puntuación promedio de las peliculas de anime no es la misma que la media general de todas las puntuaciones de anime?</span>

# %% [markdown]
# ### ANALISIS UNIVARIANTE

# %% [markdown]
# ##### MEDIDAS DE TENDENCIA CENTRAL

# %%
media= anime_num.mean()
mediana= anime_num.median()
moda= anime_num.mode().iloc[0]
des_stdar= anime_num.std()

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10,7))
sns.set_theme(rc={"grid.alpha": 0.1,"grid.color": "grey"})
fig.suptitle("VARIABLES NUMERICAS", color="Grey",fontsize=20)
plt.legend()


sns.histplot(anime_num["Score"], kde=True, ax=axes[0,0],color="limegreen", bins=12)
axes[0,0].set_title("SCORE",color="Grey", fontsize=15)
axes[0,0].set_yscale("log")
axes[0,0].tick_params(axis="y", colors="grey")
axes[0,0].tick_params(axis="x",colors="grey")
axes[0,0].set_ylabel("COUNT", color="Grey", fontsize=15)
axes[0,0].set_xlabel("SCORE",color="Grey", fontsize=15)
axes[0,0].axvline(media["Score"], color="#AF7AC5", linestyle="dashed",linewidth=3, label=f"Mean:{media['Score']:.2f}")
axes[0,0].axvline(mediana["Score"],color="#5499C7", linestyle="dotted", linewidth=2, label=f"Median: {mediana['Score']:.2f}")
axes[0,0].axvline(moda["Score"], color="#EDBB99", linestyle="solid",linewidth=2,label=f"Mode:{moda['Score']:.2f}")
axes[0,0].axvline(des_stdar["Score"], color="#CD6155", linestyle="dashdot",linewidth=2, label=f"Stdr:{des_stdar['Score']:.2f}")


sns.histplot(anime_num["Duracion"],kde=True,ax=axes[0,1], color= "#45B39D", bins= 12)
axes[0,1].set_title("DURACION",color="Grey",fontsize=15)
axes[0,1].set_yscale("log") 
axes[0,1].tick_params(axis="y",colors="grey")
axes[0,1].tick_params(axis="x", colors="grey")
axes[0,1].set_ylabel("COUNT",color="Grey", fontsize=15)
axes[0,1].set_xlabel("DURACION", color="Grey",fontsize= 15)
axes[0,1].axvline(media["Duracion"], color="#AF7AC5",linestyle="dashed", linewidth=3, label=f"Mean:{media['Duracion']:.2f}")
axes[0,1].axvline(mediana["Duracion"], color="#5499C7", linestyle="dotted", linewidth=2, label=f"Median: {mediana['Duracion']:.2f}")
axes[0,1].axvline(moda["Duracion"], color="#EDBB99", linestyle="solid",linewidth=2, label=f"Mode:{moda['Duracion']:.2f}")
axes[0,1].axvline(des_stdar["Duracion"], color="#CD6155", linestyle="dashdot",linewidth=2, label=f"Stdr:{des_stdar['Duracion']:.2f}")


sns.histplot(anime_num["Members"],kde=True, ax=axes[1,0],color= "#52BE80", bins= 12)
axes[1,0].set_title("MEMBERS",color="Grey",fontsize=15)
axes[1,0].set_yscale("log") 
axes[1,0].tick_params(axis="y",colors="grey")
axes[1,0].tick_params(axis="x", colors="grey")
axes[1,0].set_ylabel("COUNT",color="Grey", fontsize=15)
axes[1,0].set_xlabel("MEMBERS", color= "Grey",fontsize= 15)
axes[1,0].axvline(media["Members"], color="#AF7AC5", linestyle="dashed", linewidth=3, label=f"Mean:{media['Members']:.2f}")
axes[1,0].axvline(mediana["Members"], color="#5499C7", linestyle="dotted", linewidth=2, label=f"Median: {mediana['Members']:.2f}")
axes[1,0].axvline(moda["Members"], color="#EDBB99", linestyle="solid",linewidth=2, label=f"Mode:{moda['Members']:.2f}")
axes[1,0].axvline(des_stdar["Members"], color="#CD6155", linestyle="dashdot",linewidth=2, label=f"Stdr:{des_stdar['Members']:.2f}")


sns.histplot(anime_num["Favorites"],kde=True, ax=axes[1,1], color="#58D68D",bins= 12 )
axes[1,1].set_title("FAVORITOS",color="Grey",fontsize=15)
axes[1,1].set_yscale("log") 
axes[1,1].tick_params(axis="y",colors="grey")
axes[1,1].tick_params(axis="x", colors="grey")
axes[1,1].set_ylabel("COUNT",color="Grey", fontsize=15)
axes[1,1].set_xlabel("FAVORITOS", color= "Grey",fontsize= 15)
axes[1,1].axvline(media["Favorites"],color="#AF7AC5",linestyle="dashed", linewidth=3, label=f"Mean:{media['Favorites']:.2f}")
axes[1,1].axvline(mediana["Favorites"], color="#5499C7", linestyle="dotted", linewidth=2,label=f"Median: {mediana['Favorites']:.2f}")
axes[1,1].axvline(moda["Favorites"],color="#EDBB99",linestyle="solid",linewidth=2, label=f"Mode:{moda['Favorites']:.2f}")
axes[1,1].axvline(des_stdar["Favorites"], color="#CD6155", linestyle="dashdot",linewidth=2, label=f"Stdr:{des_stdar['Favorites']:.2f}")




plt.tight_layout(rect=[0, 0, 0.95,1])
plt.show()

print(f"MEDIA:\n{media}")
print(f"MEDIANA:\n{mediana}")
print(f"MODA:\n{moda}")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# MEDIA:
# Score             6.549345
# Duracion         25.992366
# Popularity     7464.238606
# Members       45053.040284
# Favorites       601.596176
# Watching       2907.965006
# Completed     28969.152143
# On-Hold        1243.032122
# Dropped        1534.555514
# dtype: float64
# MEDIANA:
# Score            6.51
# Duracion        23.00
# Popularity    7518.00
# Members       3388.00
# Favorites        5.00
# Watching       113.00
# Completed     1559.00
# On-Hold         71.00
# Dropped         97.00
# dtype: float64
# MODA:
# Score            6.51
# Duracion        24.00
# Popularity    3240.00
# Members        268.00
# Favorites        0.00
# Watching         9.00
# Completed        0.00
# On-Hold          4.00
# Dropped         34.00
# Name: 0, dtype: float64

# %% [markdown]
# #### CUANTOS TIPOS DE ANIME HAY

# %%
tipo= anime_EDA["Type"]

plt.figure(figsize=(12,4))
sns.countplot(y=tipo, order=tipo.value_counts().index, palette="mako", hue= tipo)
plt.title("Qué tipo de anime es más popular", color="Grey",fontsize=20)
plt.ylabel("TYPE",color= "Grey", fontsize=15)
plt.xlabel("COUNT", color= "Grey",fontsize= 15)
plt.tick_params(axis="x", colors="grey")
plt.tick_params(axis="y", colors="grey")

total_animes= len(tipo)
for i, value in enumerate(tipo.value_counts().values):
    porcentaje=(value / total_animes) * 100
    plt.text(value+0.1, i, f"{porcentaje:.1f}%", ha="left", va="center", color="grey")

plt.show()

# %% [markdown]
# ><span style="font-size: 25px; color:#839192">Los tipos de animes mas comunes con diferencia son las series. </span>

# %% [markdown]
# ### ANALISIS BIVARIANTE

# %% [markdown]
# ##### LAS 10 SERIES Y PELICULAS DE ANIMES CON MAS PUNTUACION

# %%
anime_mov= anime_EDA[anime_EDA["Type"]== "Movie"].sort_values(by="Score", ascending=False).head(10)
anime_tv= anime_EDA[anime_EDA["Type"]== "TV"].sort_values(by="Score", ascending=False).head(10)

sns.set_theme(rc={"grid.alpha": 0.3})
plt.figure(figsize=(10, 6))

sns.lineplot(x="Score", y="English name", data=anime_mov, marker="o",color="#BB8FCE", label="PELICULAS")
plt.axhline(y=anime_mov["English name"].iloc[-1],color="black", linestyle="-", linewidth=1,alpha=0.3)
sns.lineplot(x="Score", y="English name", data=anime_tv,marker="o", color="#1ABC9C",label="SERIES DE ANIME")
plt.title("LAS 10 PELICULAS Y SERIES CON MAYOR PUNTUACION",color="grey", fontsize=18, loc="right")
plt.xlabel("SCORE",color="grey", fontsize=14)
plt.ylabel("NOMBRES", color="grey",fontsize=14)
plt.tick_params(axis="x", colors="grey")
plt.tick_params(axis="y",colors="grey")
plt.legend()

plt.tight_layout()
plt.show()

#barras

# %% [markdown]
# ##### ¿EXISTE RELACION ENTRE LA PUNTUACION MEDIA Y POPULARIDAD?:

# %%
#RELACION ENTRE LA PUNTUACION MEDIA Y LA POPULARIDAD
correlacion= anime_EDA["Popularity"].corr(anime_EDA["Score"])
correlacion
# Out:
# -0.5696536246272317

# %%
plt.figure(figsize=(9, 5))
sns.scatterplot(x="Score", y="Popularity", data=anime_EDA,alpha=0.6, hue="Score", palette="Blues")
plt.title("CORRELACION DE LA POPULARIDAD DEL ANIME Y LA PUNTUACION MEDIA", color="Grey", fontsize=15)
plt.xlabel("PUNTUACION",color="Grey", fontsize=15)
plt.ylabel("POPULARIDAD", color="Grey", fontsize=15)
plt.tick_params(axis="x",colors="grey")
plt.tick_params(axis="y", colors="grey")
plt.legend(title="PUNTUACION",loc="upper right")

plt.show()

# %% [markdown]
# ##### ¿Y LA PUNTUACION MEDIA CON ANIMES COMPLETADOS?:

# %%
#RELACION ENTRE LA PUNTUACION MEDIA Y LA POPULARIDAD
correlacion= anime_EDA["Completed"].corr(anime_EDA["Score"])
correlacion
# Out:
# 0.3717736812964454

# %%
sns.set_theme(style="whitegrid", rc={"grid.alpha": 0.1})
plt.figure(figsize=(9,5))

sns.scatterplot(x="Score",y="Completed", data=anime_EDA, hue="Score",palette="flare", alpha=0.7,edgecolor="w", linewidth=0.5)
plt.title("CORRELACION DE ANIMES COMPLETADOS Y LA PUNTUACION MEDIA",color="Grey", fontsize=15)
plt.xlabel("PUNTUACION",color="Grey",fontsize=15)
plt.ylabel("COMPLETADOS", color="Grey", fontsize=15)
plt.tick_params(axis="x",colors="grey")
plt.tick_params(axis="y", colors="grey")
sns.despine()
plt.legend(title="PUNTACION")


plt.show()
#hacer la prueba

# %% [markdown]
# ><span style="font-size: 25px; color:#839192">Correlacion positiva moderada. Influye de manera positiva, esto quiere decir que si puntuacion de animes aumenta la cantidad de animes que las personas completan. </span>

# %%
anime_EDA.groupby("Type")["Completed"].plot(kind="kde")
# Out:
# Type
# Movie      Axes(0.08,0.07;0.87x0.81)
# Music      Axes(0.08,0.07;0.87x0.81)
# ONA        Axes(0.08,0.07;0.87x0.81)
# OVA        Axes(0.08,0.07;0.87x0.81)
# Special    Axes(0.08,0.07;0.87x0.81)
# TV         Axes(0.08,0.07;0.87x0.81)
# Name: Completed, dtype: object

# %% [markdown]
# ### ANALLISIS MULTIVARIANTE

# %% [markdown]
# ##### LA RELACION ENTRE FAVORITOS, POPULARIDAD Y ANIMES COMPLETADOS

# %%
users= anime_EDA.sort_values(by="Popularity",ascending=False).head(20)

columnas= ["Popularity","Favorites","Completed"]

users.groupby("Type").agg({"Favorites":"mean","Completed":"mean"})
# Out:
#          Favorites   Completed
# Type
# Movie     0.000000   71.200000
# Music     4.000000  348.000000
# ONA       0.000000   69.666667
# OVA       0.333333   49.666667
# Special   0.500000  137.000000
# TV        0.400000   51.600000

# %%
c= users[["Popularity","Favorites","Completed"]].corr()

plt.figure(figsize=(8,5))
sns.heatmap(c, annot=True, cmap="PiYG", fmt=".2f", linewidths=.5)
plt.title("Correlación entre popularity, favorites y completed",color= "Grey", fontsize= 15)
plt.tick_params(axis="x", colors="grey")
plt.tick_params(axis="y", colors="grey")

plt.show()

# %% [markdown]
# ><span style="font-size: 20px; color:#839192">-Hay una correlacion positiva y fuerte entre popularidad y favoritos. cuando la popularidad de un anime aumenta aumenta la cantidad de favoritos </span>
# >
# ><span style="font-size: 20px; color:#839192">-Entre popularidad y completados tambien indica que los animes tenden a tener un mayor numero de usuarios que lo completan </span>
# >
# ><span style="font-size: 20px; color:#839192"> -Entre favoritos y completados hay una correlacion positiva e indica que los animes que son favoritos tienden a ser completados</span>

# %% [markdown]
# ##### RELACION ENTRE POPULARIDAD, MIEMBROS, ABANDONADOS Y PAUSADOS

# %%
users= anime_EDA.sort_values(by="Popularity",ascending=False).head(20)
columnas= ["Popularity","Members", "Dropped","On-Hold"]

users.groupby("Type").agg({"On-Hold":"mean","Dropped":"mean", "Members":"mean"})

cor= users[["Popularity","On-Hold","Members","Dropped"]].corr()
cor
# Out:
#             Popularity   On-Hold   Members   Dropped
# Popularity    1.000000  0.875171  0.999841 -0.397935
# On-Hold       0.875171  1.000000  0.879599 -0.172789
# Members       0.999841  0.879599  1.000000 -0.398890
# Dropped      -0.397935 -0.172789 -0.398890  1.000000

# %%
cor.plot(kind="bar",colormap="viridis", figsize=(10,6))
plt.title("Correlación entre Popularity, On-Hold, Dropped y Members",color= "Grey",fontsize= 15)
plt.tick_params(axis="x",colors="grey")
plt.tick_params(axis="y",colors="grey")
plt.xticks(rotation=0, ha="right")

plt.show()

# %% [markdown]
# ##### RELACION DE LA POPULARIDAD Y SCORE ENTRE ANIMES DE TIPO TV Y ANIMES DE TIPO PELICULA

# %%
tv_anime= anime_EDA[anime_EDA["Type"] =="TV"]
movie_anime= anime_EDA[anime_EDA["Type"]== "Movie"]

# %%
# SERIES DE ANIME: CORRELACION DE LA POPULARIDAD Y SCORE
tv_anime["Score"].corr(tv_anime["Popularity"])
# Out:
# -0.5196603545349098

# %%
#PELICULAS DE ANIME:CORRELACION DE LA POPULARIDAD Y SCORE
movie_anime["Score"].corr(movie_anime["Popularity"])
# Out:
# -0.6418564158189884

# %%
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
sns.scatterplot(data=tv_anime, x="Score", y="Popularity", color="#17A589", alpha=0.2)
plt.xlabel("POPULARIDAD", color="Grey", fontsize=10)
plt.ylabel("SCORE", color="Grey", fontsize=10)
plt.title("RELACION ENTRE POPULARIDAD Y SCORE DE SERIES DE ANIME", color="Grey", fontsize=12)
plt.tick_params(axis="x", colors="grey")
plt.tick_params(axis="y", colors="grey")

plt.subplot(1, 2, 2)
sns.scatterplot(data=movie_anime, x="Score", y="Popularity", color="#D98880", alpha=0.2)
plt.xlabel("POPULARIDAD", color="Grey", fontsize=10)
plt.ylabel("SCORE", color="Grey", fontsize=10)
plt.title("RELACION ENTRE POPULARIDAD Y SCORE DE PELICULAS DE ANIME", color="Grey", fontsize=12)
plt.tick_params(axis="x", colors="grey")
plt.tick_params(axis="y", colors="grey")

plt.tight_layout()
plt.show()

# %%
tv_movie=anime_EDA[anime_EDA["Type"].isin(["TV","Movie"])]

plt.figure(figsize=(12,4))
plt.suptitle("DISTRIBUCIÓN DE LA POPULARIDAD ENTRE SERIES Y PELÍCULAS DE ANIME",color="grey", fontsize=12)

plt.subplot(1,2,1)
sns.boxplot(y="Type", x="Popularity",hue="Type", data=tv_movie, palette="pink")
plt.xlabel("Popularity",color="grey", fontsize=10)

plt.subplot(1,2,2)
sns.boxplot(y="Type",x="Score", hue="Type", data=tv_movie, palette="pink")
plt.xlabel("Score",color="grey",fontsize=10)

plt.show()

# %% [markdown]
# ><span style="font-size: 20px; color:#839192"> Las peliculas de anime tienden a ser mas populares que las series de anime </span>
# >
# ><span style="font-size: 20px; color:#839192">las peliculas tienen una popularidad de 8569 y las series de 5450.22 </span>
# >
# ><span style="font-size: 20px; color:#839192">Mi conclusion es que las peliculas atraen mas a los usuarios y les genera mas interes. </span>

# %% [markdown]
# ## <span style="color:#85929E ">TEST DE HIPOTESIS </span>

# %% [markdown]
# ##### 1. ¿Existe relación entre la puntuación media y la popularidad?

# %%
correlacion, valor_p =pearsonr(anime_EDA["Score"], anime_EDA["Popularity"])

print(f"correlacion:{correlacion}")
print(f"valor p:{valor_p}")

alpha=0.05
if valor_p< alpha:
    print("Rechazamos la hipótesis nula. Hay evidencia de una correlación positiva")
else:
    print("No hay suficiente evidencia para rechazar la hipótesis nula. No hay correlación significativa")
# Out:
# correlacion:-0.5696536246272339
# valor p:0.0
# Rechazamos la hipótesis nula. Hay evidencia de una correlación positiva

# %% [markdown]
# ><span style="font-size: 20px; color:#839192"> Hay evidencia segun el nivel de significancia que he elegido. Asi que hay evidencia estadistica para afirmar que existe relacion </span>

# %% [markdown]
# ##### 2. ¿Las puntuaciones se puede ver afectada por la duracion del anime?

# %%
correlacion, p_value= pearsonr(anime_EDA["Duracion"],anime_EDA["Score"])

print(f"correlacion: {correlacion}")
print(f"Valor p: {p_value}")

alpha=0.05
if valor_p< alpha:
    print("Rechazamos la hipótesis nula. Hay evidencia de una correlación positiva")
else:
    print("No hay suficiente evidencia para rechazar la hipótesis nula. No hay correlación significativa")
# Out:
# correlacion: 0.29219114693447634
# Valor p: 1.0359315664483381e-258
# Rechazamos la hipótesis nula. Hay evidencia de una correlación positiva

# %% [markdown]
# Conclusión: Hay evidencia significativa para sugerir que la duración del anime tipo TV tiene un efecto significativo en la puntuacion media

# %% [markdown]
# ##### 3. ¿Los animes estrenados en ciertas estaciones del año pueden tener puntuaciones más altas?

# %%
season, p_value= kruskal( anime_EDA["Score"][anime_EDA["Season"]== "Spring"],
    anime_EDA["Score"][anime_EDA["Season"]== "Summer"],
    anime_EDA["Score"][anime_EDA["Season"]== "Fall"],
    anime_EDA["Score"][anime_EDA["Season"]== "Winter"])

alpha = 0.05

print("\nPrueba de Kruskal-Wallis para más de dos muestras independientes (temporadas):")
print(f"Estadístico de prueba: {season}")
print(f"Valor p: {p_value}")
print(f"Grados de libertad: {len(anime_EDA['Season'].unique()) - 1}")

alpha=0.05
if valor_p< alpha:
    print("Rechazamos la hipótesis nula. Hay evidencia de una correlación positiva")
else:
    print("No hay suficiente evidencia para rechazar la hipótesis nula. No hay correlación significativa")
# Out:
# Prueba de Kruskal-Wallis para más de dos muestras independientes (temporadas):
# Estadístico de prueba: 18.03977202614882
# Valor p: 0.00043161961917734877
# Grados de libertad: 4
# Rechazamos la hipótesis nula. Hay evidencia de una correlación positiva

# %% [markdown]
# ##### 4. ¿El número de espectadores que han completado un anime está positivamente correlacionado con su puntuación?

# %%
corr, p_value= spearmanr(anime_EDA["Completed"], anime_EDA["Score"])

alpha = 0.05
print("\nPrueba de correlación de Spearman:")
print(f"Coeficiente de correlación: {corr}")
print(f"Valor p: {p_value}")

alpha=0.05
if valor_p< alpha:
    print("Rechazamos la hipótesis nula. Hay evidencia de una correlación positiva")
else:
    print("No hay suficiente evidencia para rechazar la hipótesis nula. No hay correlación significativa")
# Out:
# Prueba de correlación de Spearman:
# Coeficiente de correlación: 0.5517404993539118
# Valor p: 0.0
# Rechazamos la hipótesis nula. Hay evidencia de una correlación positiva

# %% [markdown]
# ##### 5. ¿Tiene impacto la duración en la popularidad?

# %%
x= sm.add_constant(anime_EDA["Duracion"])
y= anime_EDA["Popularity"]

model= sm.OLS(y, x)
results= model.fit()

p_value= results.pvalues["Duracion"]
alpha= 0.05
if p_value < alpha:
    print("Se rechaza la hipótesis nula. Hay evidencia suficiente para sugerir que la duración del anime afecta la popularidad")
else:
    print("No se puede rechazar la hipótesis nula. No hay suficiente evidencia para sugerir que la duración del anime afecta la popularidad")
          

print(results.summary())
# Out:
# Se rechaza la hipótesis nula. Hay evidencia suficiente para sugerir que la duración del anime afecta la popularidad
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Popularity   R-squared:                       0.029
# Model:                            OLS   Adj. R-squared:                  0.029
# Method:                 Least Squares   F-statistic:                     397.1
# Date:                Fri, 15 Dec 2023   Prob (F-statistic):           4.34e-87
# Time:                        22:04:37   Log-Likelihood:            -1.2984e+05
# No. Observations:               13231   AIC:                         2.597e+05
# Df Residuals:                   13229   BIC:                         2.597e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       8215.4242     53.836    152.601      0.000    8109.898    8320.950
# Duracion     -28.9002      1.450    -19.929      0.000     -31.743     -26.058
# ==============================================================================
# Omnibus:                    18560.537   Durbin-Watson:                   1.407
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              854.118
# Skew:                          -0.004   Prob(JB):                    3.39e-186
# Kurtosis:                       1.755   Cond. No.                         52.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ##### 6. ¿Los animes con clasificaciones de edad más altas pueden tener menor popularidad y score, ya que restringen al público potencial?

# %%
stat_kw, p_value_kw = kruskal(
    anime_EDA["Score"][anime_EDA["Rating"] == "PG"],
    anime_EDA["Score"][anime_EDA["Rating"] == "R"],
    anime_EDA["Score"][anime_EDA["Rating"] == "G"])

print("\nPrueba de Kruskal-Wallis para más de dos muestras independientes:")
print(f"Estadístico de prueba: {stat_kw}")
print(f"Valor p: {p_value_kw}")
print(f"Grados de libertad: {len(anime_EDA['Rating'].unique()) - 1}")

alpha=0.05
if valor_p< alpha:
    print("Rechazamos la hipótesis nula. Hay evidencia de una correlación positiva")
else:
    print("No hay suficiente evidencia para rechazar la hipótesis nula. No hay correlación significativa")
# Out:
# Prueba de Kruskal-Wallis para más de dos muestras independientes:
# Estadístico de prueba: 1102.8166108711896
# Valor p: 3.360591106232621e-240
# Grados de libertad: 2
# Rechazamos la hipótesis nula. Hay evidencia de una correlación positiva

# %% [markdown]
# ##### 7.¿Hay evidencia para afirmar que la puntuación promedio de las series de anime no es la misma que la media general de todas las puntuaciones de anime?

# %%
anime_tv= anime_EDA.loc[anime_EDA["Type"]== "TV", "Score"]
anime_movie= anime_EDA.loc[anime_EDA["Type"]== "Movie","Score"]

t_tv, p_value_tv= stats.ttest_1samp(anime_tv, popmean=anime_tv.mean())
t_movie, p_value_movie= stats.ttest_1samp(anime_movie, popmean=anime_movie.mean())

print("Resultados para series de anime:")
print(f"T-statistic: {t_tv}")
print(f"P-value: {p_value_tv}")

alpha = 0.05
if p_value_tv < alpha:
    print("Rechazamos la hipótesis nula para series de anime. Hay evidencia significativa de una diferencia en las puntuaciones promedio")
else:
    print("No hay suficiente evidencia para rechazar la hipótesis nula para series de anime. No podemos concluir que haya una diferencia significativa en las puntuaciones promedio")
# Out:
# Resultados para series de anime:
# T-statistic: 0.0
# P-value: 1.0
# No hay suficiente evidencia para rechazar la hipótesis nula para series de anime. No podemos concluir que haya una diferencia significativa en las puntuaciones promedio

# %% [markdown]
# ##### 8. ¿Hay evidencia para afirmar que la puntuación promedio de las peliculas de anime no es la misma que la media general de todas las puntuaciones de anime?

# %%
anime_movie= anime_EDA.loc[anime_EDA["Type"]== "Movie","Score"]
t_movie, p_value_movie= stats.ttest_1samp(anime_movie, popmean=anime_movie.mean())
print("\nResultados para películas:")
print(f"T-statistic: {t_movie}")
print(f"P-value: {p_value_movie}")

alpha = 0.05    
if p_value_tv < alpha:
    print("Rechazamos la hipótesis nula para las peliculas de anime. Hay evidencia significativa de una diferencia en las puntuaciones promedio")
else:
    print("No hay suficiente evidencia para rechazar la hipótesis nula para las peliculas de anime. No podemos concluir que haya una diferencia significativa en las puntuaciones promedio")
# Out:
# Resultados para películas:
# T-statistic: 0.0
# P-value: 1.0
# No hay suficiente evidencia para rechazar la hipótesis nula para las peliculas de anime. No podemos concluir que haya una diferencia significativa en las puntuaciones promedio
